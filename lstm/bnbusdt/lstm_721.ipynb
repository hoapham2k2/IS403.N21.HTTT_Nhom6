# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/BNBUSDT.xlsx')
df1=df.reset_index()['Close']

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00985389]
#  [0.01189263]
#  [0.01359157]
#  [0.01325178]
#  [0.01223242]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 5
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1044, 5) (1044,) (144, 5) (144,) (294, 5) (294,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00985389]
#   [0.01189263]
#   [0.01359157]
#   [0.01325178]
#   [0.01223242]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2)) 

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 17/17 [==============================] - 7s 95ms/step - loss: 0.1127 - mean_squared_error: 0.1127 - val_loss: 0.0508 - val_mean_squared_error: 0.0508
# Epoch 2/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.0375 - val_mean_squared_error: 0.0375
# Epoch 3/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0818 - mean_squared_error: 0.0818 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 4/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0696 - mean_squared_error: 0.0696 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 5/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0590 - mean_squared_error: 0.0590 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 6/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 7/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 8/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 9/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 10/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 11/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 12/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 13/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 14/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 15/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 16/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 17/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 18/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 19/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 20/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 21/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 22/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 23/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 24/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 25/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 26/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 27/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 28/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 29/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 30/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 31/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 32/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 33/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 34/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 35/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 36/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 37/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 38/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 39/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 9.6608e-04 - val_mean_squared_error: 9.6608e-04
# Epoch 40/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 41/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 42/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 43/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 9.2866e-04 - val_mean_squared_error: 9.2866e-04
# Epoch 44/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 9.8914e-04 - val_mean_squared_error: 9.8914e-04
# Epoch 45/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 46/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 47/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.2463e-04 - val_mean_squared_error: 8.2463e-04
# Epoch 48/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 49/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 50/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 8.6239e-04 - val_mean_squared_error: 8.6239e-04
# Epoch 51/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 52/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 53/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 8.7506e-04 - val_mean_squared_error: 8.7506e-04
# Epoch 54/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 8.7412e-04 - val_mean_squared_error: 8.7412e-04
# Epoch 55/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 56/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 8.2976e-04 - val_mean_squared_error: 8.2976e-04
# Epoch 57/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 9.1704e-04 - val_mean_squared_error: 9.1704e-04
# Epoch 58/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 8.0595e-04 - val_mean_squared_error: 8.0595e-04
# Epoch 59/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.3478e-04 - val_mean_squared_error: 9.3478e-04
# Epoch 60/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 8.6281e-04 - val_mean_squared_error: 8.6281e-04
# Epoch 61/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 9.0462e-04 - val_mean_squared_error: 9.0462e-04
# Epoch 62/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 8.3111e-04 - val_mean_squared_error: 8.3111e-04
# Epoch 63/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 8.5432e-04 - val_mean_squared_error: 8.5432e-04
# Epoch 64/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 7.3895e-04 - val_mean_squared_error: 7.3895e-04
# Epoch 65/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.4541e-04 - val_mean_squared_error: 8.4541e-04
# Epoch 66/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 7.9719e-04 - val_mean_squared_error: 7.9719e-04
# Epoch 67/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.5125e-04 - val_mean_squared_error: 6.5125e-04
# Epoch 68/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.5707e-04 - val_mean_squared_error: 8.5707e-04
# Epoch 69/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.9182e-04 - val_mean_squared_error: 7.9182e-04
# Epoch 70/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.3199e-04 - val_mean_squared_error: 9.3199e-04
# Epoch 71/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 7.6222e-04 - val_mean_squared_error: 7.6222e-04
# Epoch 72/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.8695e-04 - val_mean_squared_error: 6.8695e-04
# Epoch 73/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 7.1992e-04 - val_mean_squared_error: 7.1992e-04
# Epoch 74/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 8.2386e-04 - val_mean_squared_error: 8.2386e-04
# Epoch 75/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 7.5785e-04 - val_mean_squared_error: 7.5785e-04
# Epoch 76/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.2970e-04 - val_mean_squared_error: 7.2970e-04
# Epoch 77/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 6.4709e-04 - val_mean_squared_error: 6.4709e-04
# Epoch 78/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 7.1136e-04 - val_mean_squared_error: 7.1136e-04
# Epoch 79/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 6.3415e-04 - val_mean_squared_error: 6.3415e-04
# Epoch 80/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 7.7053e-04 - val_mean_squared_error: 7.7053e-04
# Epoch 81/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 6.2906e-04 - val_mean_squared_error: 6.2906e-04
# Epoch 82/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 7.8099e-04 - val_mean_squared_error: 7.8099e-04
# Epoch 83/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.7091e-04 - val_mean_squared_error: 6.7091e-04
# Epoch 84/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 7.2265e-04 - val_mean_squared_error: 7.2265e-04
# Epoch 85/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 7.2065e-04 - val_mean_squared_error: 7.2065e-04
# Epoch 86/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.5590e-04 - val_mean_squared_error: 6.5590e-04
# Epoch 87/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 7.3893e-04 - val_mean_squared_error: 7.3893e-04
# Epoch 88/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.6026e-04 - val_mean_squared_error: 6.6026e-04
# Epoch 89/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.5349e-04 - val_mean_squared_error: 6.5349e-04
# Epoch 90/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 8.0082e-04 - val_mean_squared_error: 8.0082e-04
# Epoch 91/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.3737e-04 - val_mean_squared_error: 6.3737e-04
# Epoch 92/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.8250e-04 - val_mean_squared_error: 7.8250e-04
# Epoch 93/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.2905e-04 - val_mean_squared_error: 6.2905e-04
# Epoch 94/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.5215e-04 - val_mean_squared_error: 7.5215e-04
# Epoch 95/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 7.2381e-04 - val_mean_squared_error: 7.2381e-04
# Epoch 96/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 6.4022e-04 - val_mean_squared_error: 6.4022e-04
# Epoch 97/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.3476e-04 - val_mean_squared_error: 6.3476e-04
# Epoch 98/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.5246e-04 - val_mean_squared_error: 6.5246e-04
# Epoch 99/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.7300e-04 - val_mean_squared_error: 6.7300e-04
# Epoch 100/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.7081e-04 - val_mean_squared_error: 6.7081e-04
# Epoch 101/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 8.0151e-04 - val_mean_squared_error: 8.0151e-04
# Epoch 102/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.1785e-04 - val_mean_squared_error: 6.1785e-04
# Epoch 103/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 7.4174e-04 - val_mean_squared_error: 7.4174e-04
# Epoch 104/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 7.6338e-04 - val_mean_squared_error: 7.6338e-04
# Epoch 105/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 6.2201e-04 - val_mean_squared_error: 6.2201e-04
# Epoch 106/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.3230e-04 - val_mean_squared_error: 6.3230e-04
# Epoch 107/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.4975e-04 - val_mean_squared_error: 6.4975e-04
# Epoch 108/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.6862e-04 - val_mean_squared_error: 6.6862e-04
# Epoch 109/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.0739e-04 - val_mean_squared_error: 6.0739e-04
# Epoch 110/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.4805e-04 - val_mean_squared_error: 6.4805e-04
# Epoch 111/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.6182e-04 - val_mean_squared_error: 6.6182e-04
# Epoch 112/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 6.6765e-04 - val_mean_squared_error: 6.6765e-04
# Epoch 113/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.1117e-04 - val_mean_squared_error: 6.1117e-04
# Epoch 114/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.3168e-04 - val_mean_squared_error: 6.3168e-04
# Epoch 115/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.2947e-04 - val_mean_squared_error: 6.2947e-04
# Epoch 116/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.1286e-04 - val_mean_squared_error: 6.1286e-04
# Epoch 117/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.3848e-04 - val_mean_squared_error: 6.3848e-04
# Epoch 118/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.1912e-04 - val_mean_squared_error: 6.1912e-04
# Epoch 119/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.2223e-04 - val_mean_squared_error: 6.2223e-04
# Epoch 120/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.1885e-04 - val_mean_squared_error: 6.1885e-04
# Epoch 121/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.3496e-04 - val_mean_squared_error: 6.3496e-04
# Epoch 122/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.7694e-04 - val_mean_squared_error: 6.7694e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.3074e-04 - val_mean_squared_error: 6.3074e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.2068e-04 - val_mean_squared_error: 6.2068e-04
# Epoch 125/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.0387e-04 - val_mean_squared_error: 6.0387e-04
# Epoch 126/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.1596e-04 - val_mean_squared_error: 6.1596e-04
# Epoch 127/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.9618e-04 - val_mean_squared_error: 6.9618e-04
# Epoch 128/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.0874e-04 - val_mean_squared_error: 6.0874e-04
# Epoch 129/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.1401e-04 - val_mean_squared_error: 6.1401e-04
# Epoch 130/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 6.1743e-04 - val_mean_squared_error: 6.1743e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.8152e-04 - val_mean_squared_error: 6.8152e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1355e-04 - val_mean_squared_error: 6.1355e-04
# Epoch 133/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.1315e-04 - val_mean_squared_error: 6.1315e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.5995e-04 - val_mean_squared_error: 6.5995e-04
# Epoch 135/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.1386e-04 - val_mean_squared_error: 6.1386e-04
# Epoch 136/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.2030e-04 - val_mean_squared_error: 6.2030e-04
# Epoch 137/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.1018e-04 - val_mean_squared_error: 6.1018e-04
# Epoch 138/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.0990e-04 - val_mean_squared_error: 6.0990e-04
# Epoch 139/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.1327e-04 - val_mean_squared_error: 6.1327e-04
# Epoch 140/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.2045e-04 - val_mean_squared_error: 6.2045e-04
# Epoch 141/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.1082e-04 - val_mean_squared_error: 6.1082e-04
# Epoch 142/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.0746e-04 - val_mean_squared_error: 6.0746e-04
# Epoch 143/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.2723e-04 - val_mean_squared_error: 6.2723e-04
# Epoch 144/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.1347e-04 - val_mean_squared_error: 6.1347e-04
# Epoch 145/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.1823e-04 - val_mean_squared_error: 6.1823e-04
# Epoch 146/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.1590e-04 - val_mean_squared_error: 6.1590e-04
# Epoch 147/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.2203e-04 - val_mean_squared_error: 6.2203e-04
# Epoch 148/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.2912e-04 - val_mean_squared_error: 6.2912e-04
# Epoch 149/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.0767e-04 - val_mean_squared_error: 6.0767e-04
# Epoch 150/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.0738e-04 - val_mean_squared_error: 6.0738e-04
# Epoch 150: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# (1044, 1) (294, 1) (144, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1044,) (294,) (144,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[0.07693938]
#  [0.07997447]
#  [0.08139157]
#  [0.08118466]
#  [0.08179519]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.062]
#  [0.067]
#  [0.066]
#  [0.071]
#  [0.072]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))
# Out:
# Train Mean Squared Error: 0.11175639100041275
# Test Mean Squared Error: 0.07253059775012158
# Val Mean Squared Error: 0.02096965520265479
# Train Score: 0.11 RMSE
# Test Score: 0.07 RMSE
# Val Score: 0.02 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 24.22154069563876
# Test Mean Absolute Percentage Error: 6.402958514814877
# Val Mean Absolute Percentage Error: 4.777083695089272
# Train Score: 24.22 MAPE
# Test Score: 6.40 MAPE
# Val Score: 4.78 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (5, 1)
# -----------------
# day  1  have input =  [0.114509   0.1114509  0.11314985 0.10941216 0.11043153]
# day  1  have output =  0.11091794
# -----------------
# day  2  have input =  [0.1114509  0.11314985 0.10941216 0.11043153 0.11091794]
# day  2  have output =  0.109712794
# -----------------
# day  3  have input =  [0.11314985 0.10941216 0.11043153 0.11091794 0.10971279]
# day  3  have output =  0.10951474
# -----------------
# day  4  have input =  [0.10941216 0.11043153 0.11091794 0.10971279 0.10951474]
# day  4  have output =  0.10838807
# -----------------
# day  5  have input =  [0.11043153 0.11091794 0.10971279 0.10951474 0.10838807]
# day  5  have output =  0.10862185
# -----------------
# day  6  have input =  [0.11091794 0.10971279 0.10951474 0.10838807 0.10862185]
# day  6  have output =  0.10834217
# -----------------
# day  7  have input =  [0.10971279 0.10951474 0.10838807 0.10862185 0.10834217]
# day  7  have output =  0.107663974
# -----------------
# day  8  have input =  [0.10951474 0.10838807 0.10862185 0.10834217 0.10766397]
# day  8  have output =  0.10728122
# -----------------
# day  9  have input =  [0.10838807 0.10862185 0.10834217 0.10766397 0.10728122]
# day  9  have output =  0.106806464
# -----------------
# day  10  have input =  [0.10862185 0.10834217 0.10766397 0.10728122 0.10680646]
# day  10  have output =  0.106645316
# -----------------
# day  11  have input =  [0.10834217 0.10766397 0.10728122 0.10680646 0.10664532]
# day  11  have output =  0.10624385
# -----------------
# day  12  have input =  [0.10766397 0.10728122 0.10680646 0.10664532 0.10624385]
# day  12  have output =  0.10578181
# -----------------
# day  13  have input =  [0.10728122 0.10680646 0.10664532 0.10624385 0.10578181]
# day  13  have output =  0.10543313
# -----------------
# day  14  have input =  [0.10680646 0.10664532 0.10624385 0.10578181 0.10543313]
# day  14  have output =  0.10509089
# -----------------
# day  15  have input =  [0.10664532 0.10624385 0.10578181 0.10543313 0.10509089]
# day  15  have output =  0.10479897
# -----------------
# day  16  have input =  [0.10624385 0.10578181 0.10543313 0.10509089 0.10479897]
# day  16  have output =  0.1044255
# -----------------
# day  17  have input =  [0.10578181 0.10543313 0.10509089 0.10479897 0.1044255 ]
# day  17  have output =  0.10406351
# -----------------
# day  18  have input =  [0.10543313 0.10509089 0.10479897 0.1044255  0.10406351]
# day  18  have output =  0.1037461
# -----------------
# day  19  have input =  [0.10509089 0.10479897 0.1044255  0.10406351 0.1037461 ]
# day  19  have output =  0.10343285
# -----------------
# day  20  have input =  [0.10479897 0.1044255  0.10406351 0.1037461  0.10343285]
# day  20  have output =  0.10312252
# -----------------
# day  21  have input =  [0.1044255  0.10406351 0.1037461  0.10343285 0.10312252]
# day  21  have output =  0.1027939
# -----------------
# day  22  have input =  [0.10406351 0.1037461  0.10343285 0.10312252 0.1027939 ]
# day  22  have output =  0.10248184
# -----------------
# day  23  have input =  [0.1037461  0.10343285 0.10312252 0.1027939  0.10248184]
# day  23  have output =  0.1021865
# -----------------
# day  24  have input =  [0.10343285 0.10312252 0.1027939  0.10248184 0.1021865 ]
# day  24  have output =  0.10189245
# -----------------
# day  25  have input =  [0.10312252 0.1027939  0.10248184 0.1021865  0.10189245]
# day  25  have output =  0.10159912
# -----------------
# day  26  have input =  [0.1027939  0.10248184 0.1021865  0.10189245 0.10159912]
# day  26  have output =  0.101306684
# -----------------
# day  27  have input =  [0.10248184 0.1021865  0.10189245 0.10159912 0.10130668]
# day  27  have output =  0.101025105
# -----------------
# day  28  have input =  [0.1021865  0.10189245 0.10159912 0.10130668 0.1010251 ]
# day  28  have output =  0.10075057
# -----------------
# day  29  have input =  [0.10189245 0.10159912 0.10130668 0.1010251  0.10075057]
# day  29  have output =  0.10047816
# -----------------
# day  30  have input =  [0.10159912 0.10130668 0.1010251  0.10075057 0.10047816]
# day  30  have output =  0.10020891

# %%
#in ra 30 ngày tiếp theo
print("Du doan 30 ngay tiep theo: ", lst_output)
# Out:
# Du doan 30 ngay tiep theo:  [0.11091794, 0.109712794, 0.10951474, 0.10838807, 0.10862185, 0.10834217, 0.107663974, 0.10728122, 0.106806464, 0.106645316, 0.10624385, 0.10578181, 0.10543313, 0.10509089, 0.10479897, 0.1044255, 0.10406351, 0.1037461, 0.10343285, 0.10312252, 0.1027939, 0.10248184, 0.1021865, 0.10189245, 0.10159912, 0.101306684, 0.101025105, 0.10075057, 0.10047816, 0.10020891]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.052]
#  [0.058]
#  [0.063]
#  [0.062]
#  [0.059]]
# [[1.319]
#  [1.309]
#  [1.23 ]
#  [1.28 ]
#  [1.21 ]]
# [[0.406]
#  [0.406]
#  [0.401]
#  [0.386]
#  [0.39 ]]
# [[0.34943148]
#  [0.34588474]
#  [0.3453019 ]
#  [0.34198606]
#  [0.3426741 ]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
