# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../Dataset/ADAUSDT.xlsx')
df1=df.reset_index()['Close']

# %%
#đảo ngược dữ liệu
df1=df1[::-1]
df=df[::-1]

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00985389]
#  [0.01189263]
#  [0.01359157]
#  [0.01325178]
#  [0.01223242]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 5
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1044, 5) (1044,) (144, 5) (144,) (294, 5) (294,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00985389]
#   [0.01189263]
#   [0.01359157]
#   [0.01325178]
#   [0.01223242]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(4))
model.add(Dropout(0.2)) 

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.01), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=150,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/150
# 17/17 [==============================] - 7s 83ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 2/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 3/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 7.1757e-04 - val_mean_squared_error: 7.1757e-04
# Epoch 4/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.4383e-04 - val_mean_squared_error: 6.4383e-04
# Epoch 5/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.6979e-04 - val_mean_squared_error: 6.6979e-04
# Epoch 6/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 5.6384e-04 - val_mean_squared_error: 5.6384e-04
# Epoch 7/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.1267e-04 - val_mean_squared_error: 6.1267e-04
# Epoch 8/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.6280e-04 - val_mean_squared_error: 6.6280e-04
# Epoch 9/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 7.6933e-04 - val_mean_squared_error: 7.6933e-04
# Epoch 10/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.5006e-04 - val_mean_squared_error: 6.5006e-04
# Epoch 11/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 5.2847e-04 - val_mean_squared_error: 5.2847e-04
# Epoch 12/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 5.3109e-04 - val_mean_squared_error: 5.3109e-04
# Epoch 13/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.1423e-04 - val_mean_squared_error: 5.1423e-04
# Epoch 14/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 5.5307e-04 - val_mean_squared_error: 5.5307e-04
# Epoch 15/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 16/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.0623e-04 - val_mean_squared_error: 6.0623e-04
# Epoch 17/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 9.2695e-04 - val_mean_squared_error: 9.2695e-04
# Epoch 18/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 5.2848e-04 - val_mean_squared_error: 5.2848e-04
# Epoch 19/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 20/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 5.5166e-04 - val_mean_squared_error: 5.5166e-04
# Epoch 21/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 5.5514e-04 - val_mean_squared_error: 5.5514e-04
# Epoch 22/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 5.4289e-04 - val_mean_squared_error: 5.4289e-04
# Epoch 23/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 4.9904e-04 - val_mean_squared_error: 4.9904e-04
# Epoch 24/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 8.2733e-04 - val_mean_squared_error: 8.2733e-04
# Epoch 25/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.2854e-04 - val_mean_squared_error: 6.2854e-04
# Epoch 26/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 5.3419e-04 - val_mean_squared_error: 5.3419e-04
# Epoch 27/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 5.0886e-04 - val_mean_squared_error: 5.0886e-04
# Epoch 28/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 4.6239e-04 - val_mean_squared_error: 4.6239e-04
# Epoch 29/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 9.5873e-04 - val_mean_squared_error: 9.5873e-04
# Epoch 30/150
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 4.3953e-04 - val_mean_squared_error: 4.3953e-04
# Epoch 31/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.4997e-04 - val_mean_squared_error: 5.4997e-04
# Epoch 32/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 4.9253e-04 - val_mean_squared_error: 4.9253e-04
# Epoch 33/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 34/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 4.2662e-04 - val_mean_squared_error: 4.2662e-04
# Epoch 35/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.6223e-04 - val_mean_squared_error: 4.6223e-04
# Epoch 36/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 4.1121e-04 - val_mean_squared_error: 4.1121e-04
# Epoch 37/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.7766e-04 - val_mean_squared_error: 6.7766e-04
# Epoch 38/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.2479e-04 - val_mean_squared_error: 4.2479e-04
# Epoch 39/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.0163e-04 - val_mean_squared_error: 6.0163e-04
# Epoch 40/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.3584e-04 - val_mean_squared_error: 3.3584e-04
# Epoch 41/150
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 3.6359e-04 - val_mean_squared_error: 3.6359e-04
# Epoch 42/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.7456e-04 - val_mean_squared_error: 5.7456e-04
# Epoch 43/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 3.5671e-04 - val_mean_squared_error: 3.5671e-04
# Epoch 44/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.0666e-04 - val_mean_squared_error: 3.0666e-04
# Epoch 45/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.8113e-04 - val_mean_squared_error: 6.8113e-04
# Epoch 46/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 3.3048e-04 - val_mean_squared_error: 3.3048e-04
# Epoch 47/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.9911e-04 - val_mean_squared_error: 2.9911e-04
# Epoch 48/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 4.4840e-04 - val_mean_squared_error: 4.4840e-04
# Epoch 49/150
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 50/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 3.3919e-04 - val_mean_squared_error: 3.3919e-04
# Epoch 51/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 9.5892e-04 - val_mean_squared_error: 9.5892e-04
# Epoch 52/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 3.2398e-04 - val_mean_squared_error: 3.2398e-04
# Epoch 53/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 4.8502e-04 - val_mean_squared_error: 4.8502e-04
# Epoch 54/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.5656e-04 - val_mean_squared_error: 2.5656e-04
# Epoch 55/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.4652e-04 - val_mean_squared_error: 3.4652e-04
# Epoch 56/150
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.3483e-04 - val_mean_squared_error: 3.3483e-04
# Epoch 57/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.5128e-04 - val_mean_squared_error: 2.5128e-04
# Epoch 58/150
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.5676e-04 - val_mean_squared_error: 6.5676e-04
# Epoch 59/150
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.9200e-04 - val_mean_squared_error: 2.9200e-04
# Epoch 60/150
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 5.3799e-04 - val_mean_squared_error: 5.3799e-04
# Epoch 61/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.5028e-04 - val_mean_squared_error: 3.5028e-04
# Epoch 62/150
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.5285e-04 - val_mean_squared_error: 6.5285e-04
# Epoch 63/150
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 4.1048e-04 - val_mean_squared_error: 4.1048e-04
# Epoch 64/150
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 4.9470e-04 - val_mean_squared_error: 4.9470e-04
# Epoch 65/150
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.7285e-04 - val_mean_squared_error: 6.7285e-04
# Epoch 66/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.2657e-04 - val_mean_squared_error: 3.2657e-04
# Epoch 67/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.2445e-04 - val_mean_squared_error: 2.2445e-04
# Epoch 68/150
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 3.0619e-04 - val_mean_squared_error: 3.0619e-04
# Epoch 69/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 4.9485e-04 - val_mean_squared_error: 4.9485e-04
# Epoch 70/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 3.3333e-04 - val_mean_squared_error: 3.3333e-04
# Epoch 71/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.8310e-04 - val_mean_squared_error: 2.8310e-04
# Epoch 72/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.3787e-04 - val_mean_squared_error: 2.3787e-04
# Epoch 73/150
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 7.0986e-04 - val_mean_squared_error: 7.0986e-04
# Epoch 74/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.0924e-04 - val_mean_squared_error: 4.0924e-04
# Epoch 75/150
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.0835e-04 - val_mean_squared_error: 2.0835e-04
# Epoch 76/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 4.5901e-04 - val_mean_squared_error: 4.5901e-04
# Epoch 77/150
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 3.2890e-04 - val_mean_squared_error: 3.2890e-04
# Epoch 78/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 2.4596e-04 - val_mean_squared_error: 2.4596e-04
# Epoch 79/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 5.0150e-04 - val_mean_squared_error: 5.0150e-04
# Epoch 80/150
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.9889e-04 - val_mean_squared_error: 6.9889e-04
# Epoch 81/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.8777e-04 - val_mean_squared_error: 4.8777e-04
# Epoch 82/150
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 9.3653e-04 - val_mean_squared_error: 9.3653e-04
# Epoch 83/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 8.2332e-04 - val_mean_squared_error: 8.2332e-04
# Epoch 84/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 5.8495e-04 - val_mean_squared_error: 5.8495e-04
# Epoch 85/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 2.4522e-04 - val_mean_squared_error: 2.4522e-04
# Epoch 86/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 2.7690e-04 - val_mean_squared_error: 2.7690e-04
# Epoch 87/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.5098e-04 - val_mean_squared_error: 2.5098e-04
# Epoch 88/150
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 7.7249e-04 - val_mean_squared_error: 7.7249e-04
# Epoch 89/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.0609e-04 - val_mean_squared_error: 6.0609e-04
# Epoch 90/150
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.1101e-04 - val_mean_squared_error: 2.1101e-04
# Epoch 91/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.6531e-04 - val_mean_squared_error: 2.6531e-04
# Epoch 92/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 3.3820e-04 - val_mean_squared_error: 3.3820e-04
# Epoch 93/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.2992e-04 - val_mean_squared_error: 3.2992e-04
# Epoch 94/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.3374e-04 - val_mean_squared_error: 3.3374e-04
# Epoch 95/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.7218e-04 - val_mean_squared_error: 6.7218e-04
# Epoch 96/150
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.5215e-04 - val_mean_squared_error: 3.5215e-04
# Epoch 97/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 2.5617e-04 - val_mean_squared_error: 2.5617e-04
# Epoch 98/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 3.7422e-04 - val_mean_squared_error: 3.7422e-04
# Epoch 99/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 3.3770e-04 - val_mean_squared_error: 3.3770e-04
# Epoch 100/150
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.6625e-04 - val_mean_squared_error: 2.6625e-04
# Epoch 100: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# (1044, 1) (294, 1) (144, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1044,) (294,) (144,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[0.12953438]
#  [0.13154359]
#  [0.13552994]
#  [0.13543706]
#  [0.138226  ]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.062]
#  [0.067]
#  [0.066]
#  [0.071]
#  [0.072]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))
# Out:
# Train Mean Squared Error: 0.11134851604421003
# Test Mean Squared Error: 0.048021206350181776
# Val Mean Squared Error: 0.039857749693436056
# Train Score: 0.11 RMSE
# Test Score: 0.05 RMSE
# Val Score: 0.04 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 76.71608722147111
# Test Mean Absolute Percentage Error: 5.313119775877412
# Val Mean Absolute Percentage Error: 11.670444677432718
# Train Score: 76.72 MAPE
# Test Score: 5.31 MAPE
# Val Score: 11.67 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (5, 1)
# -----------------
# day  1  have input =  [0.114509   0.1114509  0.11314985 0.10941216 0.11043153]
# day  1  have output =  0.12253563
# -----------------
# day  2  have input =  [0.1114509  0.11314985 0.10941216 0.11043153 0.12253563]
# day  2  have output =  0.13088024
# -----------------
# day  3  have input =  [0.11314985 0.10941216 0.11043153 0.12253563 0.13088024]
# day  3  have output =  0.13813367
# -----------------
# day  4  have input =  [0.10941216 0.11043153 0.12253563 0.13088024 0.13813367]
# day  4  have output =  0.14370856
# -----------------
# day  5  have input =  [0.11043153 0.12253563 0.13088024 0.13813367 0.14370856]
# day  5  have output =  0.14885628
# -----------------
# day  6  have input =  [0.12253563 0.13088024 0.13813367 0.14370856 0.14885628]
# day  6  have output =  0.15401632
# -----------------
# day  7  have input =  [0.13088024 0.13813367 0.14370856 0.14885628 0.15401632]
# day  7  have output =  0.15890525
# -----------------
# day  8  have input =  [0.13813367 0.14370856 0.14885628 0.15401632 0.15890525]
# day  8  have output =  0.16348614
# -----------------
# day  9  have input =  [0.14370856 0.14885628 0.15401632 0.15890525 0.16348614]
# day  9  have output =  0.1677029
# -----------------
# day  10  have input =  [0.14885628 0.15401632 0.15890525 0.16348614 0.1677029 ]
# day  10  have output =  0.17161095
# -----------------
# day  11  have input =  [0.15401632 0.15890525 0.16348614 0.1677029  0.17161095]
# day  11  have output =  0.17525595
# -----------------
# day  12  have input =  [0.15890525 0.16348614 0.1677029  0.17161095 0.17525595]
# day  12  have output =  0.17865986
# -----------------
# day  13  have input =  [0.16348614 0.1677029  0.17161095 0.17525595 0.17865986]
# day  13  have output =  0.18183768
# -----------------
# day  14  have input =  [0.1677029  0.17161095 0.17525595 0.17865986 0.18183768]
# day  14  have output =  0.18480042
# -----------------
# day  15  have input =  [0.17161095 0.17525595 0.17865986 0.18183768 0.18480042]
# day  15  have output =  0.18756203
# -----------------
# day  16  have input =  [0.17525595 0.17865986 0.18183768 0.18480042 0.18756203]
# day  16  have output =  0.19013683
# -----------------
# day  17  have input =  [0.17865986 0.18183768 0.18480042 0.18756203 0.19013683]
# day  17  have output =  0.19253802
# -----------------
# day  18  have input =  [0.18183768 0.18480042 0.18756203 0.19013683 0.19253802]
# day  18  have output =  0.1947776
# -----------------
# day  19  have input =  [0.18480042 0.18756203 0.19013683 0.19253802 0.19477759]
# day  19  have output =  0.1968664
# -----------------
# day  20  have input =  [0.18756203 0.19013683 0.19253802 0.19477759 0.19686639]
# day  20  have output =  0.19881456
# -----------------
# day  21  have input =  [0.19013683 0.19253802 0.19477759 0.19686639 0.19881456]
# day  21  have output =  0.20063156
# -----------------
# day  22  have input =  [0.19253802 0.19477759 0.19686639 0.19881456 0.20063156]
# day  22  have output =  0.2023263
# -----------------
# day  23  have input =  [0.19477759 0.19686639 0.19881456 0.20063156 0.2023263 ]
# day  23  have output =  0.203907
# -----------------
# day  24  have input =  [0.19686639 0.19881456 0.20063156 0.2023263  0.203907  ]
# day  24  have output =  0.20538142
# -----------------
# day  25  have input =  [0.19881456 0.20063156 0.2023263  0.203907   0.20538142]
# day  25  have output =  0.20675664
# -----------------
# day  26  have input =  [0.20063156 0.2023263  0.203907   0.20538142 0.20675664]
# day  26  have output =  0.20803939
# -----------------
# day  27  have input =  [0.2023263  0.203907   0.20538142 0.20675664 0.20803939]
# day  27  have output =  0.20923588
# -----------------
# day  28  have input =  [0.203907   0.20538142 0.20675664 0.20803939 0.20923588]
# day  28  have output =  0.21035191
# -----------------
# day  29  have input =  [0.20538142 0.20675664 0.20803939 0.20923588 0.21035191]
# day  29  have output =  0.21139292
# -----------------
# day  30  have input =  [0.20675664 0.20803939 0.20923588 0.21035191 0.21139292]
# day  30  have output =  0.21236393

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.12253563, 0.13088024, 0.13813367, 0.14370856, 0.14885628, 0.15401632, 0.15890525, 0.16348614, 0.1677029, 0.17161095, 0.17525595, 0.17865986, 0.18183768, 0.18480042, 0.18756203, 0.19013683, 0.19253802, 0.1947776, 0.1968664, 0.19881456, 0.20063156, 0.2023263, 0.203907, 0.20538142, 0.20675664, 0.20803939, 0.20923588, 0.21035191, 0.21139292, 0.21236393]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.052]
#  [0.058]
#  [0.063]
#  [0.062]
#  [0.059]]
# [[1.319]
#  [1.309]
#  [1.23 ]
#  [1.28 ]
#  [1.21 ]]
# [[0.406]
#  [0.406]
#  [0.401]
#  [0.386]
#  [0.39 ]]
# [[0.38362235]
#  [0.40818053]
#  [0.4295274 ]
#  [0.44593427]
#  [0.46108404]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
