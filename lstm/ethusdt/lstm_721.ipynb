# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/ETHUSDT.xlsx')
df1=df.reset_index()['Close']

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00985389]
#  [0.01189263]
#  [0.01359157]
#  [0.01325178]
#  [0.01223242]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 5
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1044, 5) (1044,) (144, 5) (144,) (294, 5) (294,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00985389]
#   [0.01189263]
#   [0.01359157]
#   [0.01325178]
#   [0.01223242]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2)) 

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1044, 5, 1) (294, 5, 1) (144, 5, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 17/17 [==============================] - 8s 98ms/step - loss: 0.1097 - mean_squared_error: 0.1097 - val_loss: 0.0515 - val_mean_squared_error: 0.0515
# Epoch 2/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0962 - mean_squared_error: 0.0962 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
# Epoch 3/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0849 - mean_squared_error: 0.0849 - val_loss: 0.0303 - val_mean_squared_error: 0.0303
# Epoch 4/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0721 - mean_squared_error: 0.0721 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 5/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0612 - mean_squared_error: 0.0612 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 6/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0516 - mean_squared_error: 0.0516 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 7/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 8/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 9/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 10/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 11/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 12/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 13/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 14/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 15/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 16/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 17/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 18/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 19/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 20/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 21/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 22/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 23/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 24/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 25/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 26/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 27/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 28/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 29/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 30/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 31/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 32/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 33/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 34/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 35/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 36/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 37/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 38/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 39/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 40/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 41/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 8.9827e-04 - val_mean_squared_error: 8.9827e-04
# Epoch 42/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 43/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 44/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 45/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 46/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 47/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 9.2514e-04 - val_mean_squared_error: 9.2514e-04
# Epoch 48/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 9.7416e-04 - val_mean_squared_error: 9.7416e-04
# Epoch 49/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 50/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 51/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 9.5928e-04 - val_mean_squared_error: 9.5928e-04
# Epoch 52/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 8.5450e-04 - val_mean_squared_error: 8.5450e-04
# Epoch 53/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 9.5401e-04 - val_mean_squared_error: 9.5401e-04
# Epoch 54/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 55/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 9.4700e-04 - val_mean_squared_error: 9.4700e-04
# Epoch 56/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 9.7124e-04 - val_mean_squared_error: 9.7124e-04
# Epoch 57/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 9.3649e-04 - val_mean_squared_error: 9.3649e-04
# Epoch 58/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 9.0515e-04 - val_mean_squared_error: 9.0515e-04
# Epoch 59/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 8.2659e-04 - val_mean_squared_error: 8.2659e-04
# Epoch 60/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 8.7440e-04 - val_mean_squared_error: 8.7440e-04
# Epoch 61/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 7.6757e-04 - val_mean_squared_error: 7.6757e-04
# Epoch 62/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 8.5309e-04 - val_mean_squared_error: 8.5309e-04
# Epoch 63/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 9.2069e-04 - val_mean_squared_error: 9.2069e-04
# Epoch 64/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 8.1549e-04 - val_mean_squared_error: 8.1549e-04
# Epoch 65/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.9777e-04 - val_mean_squared_error: 8.9777e-04
# Epoch 66/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 7.6203e-04 - val_mean_squared_error: 7.6203e-04
# Epoch 67/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 9.4656e-04 - val_mean_squared_error: 9.4656e-04
# Epoch 68/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.7923e-04 - val_mean_squared_error: 8.7923e-04
# Epoch 69/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 8.0229e-04 - val_mean_squared_error: 8.0229e-04
# Epoch 70/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 8.3875e-04 - val_mean_squared_error: 8.3875e-04
# Epoch 71/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 8.9277e-04 - val_mean_squared_error: 8.9277e-04
# Epoch 72/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 8.1494e-04 - val_mean_squared_error: 8.1494e-04
# Epoch 73/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.9990e-04 - val_mean_squared_error: 6.9990e-04
# Epoch 74/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 7.1487e-04 - val_mean_squared_error: 7.1487e-04
# Epoch 75/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 7.1385e-04 - val_mean_squared_error: 7.1385e-04
# Epoch 76/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 8.4835e-04 - val_mean_squared_error: 8.4835e-04
# Epoch 77/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 7.5455e-04 - val_mean_squared_error: 7.5455e-04
# Epoch 78/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 6.7794e-04 - val_mean_squared_error: 6.7794e-04
# Epoch 79/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 8.9067e-04 - val_mean_squared_error: 8.9067e-04
# Epoch 80/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.4784e-04 - val_mean_squared_error: 6.4784e-04
# Epoch 81/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.0004e-04 - val_mean_squared_error: 7.0004e-04
# Epoch 82/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 83/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.2725e-04 - val_mean_squared_error: 6.2725e-04
# Epoch 84/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.6696e-04 - val_mean_squared_error: 6.6696e-04
# Epoch 85/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 8.3099e-04 - val_mean_squared_error: 8.3099e-04
# Epoch 86/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 6.3645e-04 - val_mean_squared_error: 6.3645e-04
# Epoch 87/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 8.0260e-04 - val_mean_squared_error: 8.0260e-04
# Epoch 88/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.7905e-04 - val_mean_squared_error: 6.7905e-04
# Epoch 89/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 7.2641e-04 - val_mean_squared_error: 7.2641e-04
# Epoch 90/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.7303e-04 - val_mean_squared_error: 6.7303e-04
# Epoch 91/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 7.8591e-04 - val_mean_squared_error: 7.8591e-04
# Epoch 92/300
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.6943e-04 - val_mean_squared_error: 6.6943e-04
# Epoch 93/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.6809e-04 - val_mean_squared_error: 6.6809e-04
# Epoch 94/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.4072e-04 - val_mean_squared_error: 6.4072e-04
# Epoch 95/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 7.0771e-04 - val_mean_squared_error: 7.0771e-04
# Epoch 96/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 7.1021e-04 - val_mean_squared_error: 7.1021e-04
# Epoch 97/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 7.3436e-04 - val_mean_squared_error: 7.3436e-04
# Epoch 98/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.7069e-04 - val_mean_squared_error: 6.7069e-04
# Epoch 99/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.5772e-04 - val_mean_squared_error: 6.5772e-04
# Epoch 100/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.3578e-04 - val_mean_squared_error: 6.3578e-04
# Epoch 101/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 6.6592e-04 - val_mean_squared_error: 6.6592e-04
# Epoch 102/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 6.3414e-04 - val_mean_squared_error: 6.3414e-04
# Epoch 103/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 7.3085e-04 - val_mean_squared_error: 7.3085e-04
# Epoch 104/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 7.0149e-04 - val_mean_squared_error: 7.0149e-04
# Epoch 105/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.4306e-04 - val_mean_squared_error: 6.4306e-04
# Epoch 106/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.2437e-04 - val_mean_squared_error: 6.2437e-04
# Epoch 107/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 7.1044e-04 - val_mean_squared_error: 7.1044e-04
# Epoch 108/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.9704e-04 - val_mean_squared_error: 6.9704e-04
# Epoch 109/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.7553e-04 - val_mean_squared_error: 6.7553e-04
# Epoch 110/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.8535e-04 - val_mean_squared_error: 6.8535e-04
# Epoch 111/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.1577e-04 - val_mean_squared_error: 6.1577e-04
# Epoch 112/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.9559e-04 - val_mean_squared_error: 6.9559e-04
# Epoch 113/300
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.9942e-04 - val_mean_squared_error: 6.9942e-04
# Epoch 114/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.1440e-04 - val_mean_squared_error: 6.1440e-04
# Epoch 115/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 6.3195e-04 - val_mean_squared_error: 6.3195e-04
# Epoch 116/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.9336e-04 - val_mean_squared_error: 6.9336e-04
# Epoch 117/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1767e-04 - val_mean_squared_error: 6.1767e-04
# Epoch 118/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.3214e-04 - val_mean_squared_error: 6.3214e-04
# Epoch 119/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.5757e-04 - val_mean_squared_error: 6.5757e-04
# Epoch 120/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.6188e-04 - val_mean_squared_error: 6.6188e-04
# Epoch 121/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.2086e-04 - val_mean_squared_error: 6.2086e-04
# Epoch 122/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 7.2305e-04 - val_mean_squared_error: 7.2305e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.1396e-04 - val_mean_squared_error: 6.1396e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.9664e-04 - val_mean_squared_error: 6.9664e-04
# Epoch 125/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.3150e-04 - val_mean_squared_error: 6.3150e-04
# Epoch 126/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.1725e-04 - val_mean_squared_error: 6.1725e-04
# Epoch 127/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.4350e-04 - val_mean_squared_error: 6.4350e-04
# Epoch 128/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 7.3903e-04 - val_mean_squared_error: 7.3903e-04
# Epoch 129/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 6.1578e-04 - val_mean_squared_error: 6.1578e-04
# Epoch 130/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.6638e-04 - val_mean_squared_error: 6.6638e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.4923e-04 - val_mean_squared_error: 6.4923e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.4119e-04 - val_mean_squared_error: 6.4119e-04
# Epoch 133/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.3860e-04 - val_mean_squared_error: 6.3860e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.2437e-04 - val_mean_squared_error: 6.2437e-04
# Epoch 135/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.7137e-04 - val_mean_squared_error: 6.7137e-04
# Epoch 136/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.2581e-04 - val_mean_squared_error: 6.2581e-04
# Epoch 137/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.1316e-04 - val_mean_squared_error: 6.1316e-04
# Epoch 138/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.3584e-04 - val_mean_squared_error: 6.3584e-04
# Epoch 139/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.2360e-04 - val_mean_squared_error: 6.2360e-04
# Epoch 140/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1729e-04 - val_mean_squared_error: 6.1729e-04
# Epoch 141/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.7923e-04 - val_mean_squared_error: 6.7923e-04
# Epoch 142/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1593e-04 - val_mean_squared_error: 6.1593e-04
# Epoch 143/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.6693e-04 - val_mean_squared_error: 6.6693e-04
# Epoch 144/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.2250e-04 - val_mean_squared_error: 6.2250e-04
# Epoch 145/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.3862e-04 - val_mean_squared_error: 6.3862e-04
# Epoch 146/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 7.1821e-04 - val_mean_squared_error: 7.1821e-04
# Epoch 147/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.1566e-04 - val_mean_squared_error: 6.1566e-04
# Epoch 148/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.4038e-04 - val_mean_squared_error: 6.4038e-04
# Epoch 149/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.1217e-04 - val_mean_squared_error: 6.1217e-04
# Epoch 150/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.1973e-04 - val_mean_squared_error: 6.1973e-04
# Epoch 151/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.3453e-04 - val_mean_squared_error: 6.3453e-04
# Epoch 152/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.6287e-04 - val_mean_squared_error: 6.6287e-04
# Epoch 153/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.2392e-04 - val_mean_squared_error: 6.2392e-04
# Epoch 154/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.3073e-04 - val_mean_squared_error: 6.3073e-04
# Epoch 155/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1148e-04 - val_mean_squared_error: 6.1148e-04
# Epoch 156/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.2000e-04 - val_mean_squared_error: 6.2000e-04
# Epoch 157/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.2065e-04 - val_mean_squared_error: 6.2065e-04
# Epoch 158/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.3054e-04 - val_mean_squared_error: 6.3054e-04
# Epoch 159/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.3190e-04 - val_mean_squared_error: 6.3190e-04
# Epoch 160/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1610e-04 - val_mean_squared_error: 6.1610e-04
# Epoch 161/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 6.4261e-04 - val_mean_squared_error: 6.4261e-04
# Epoch 162/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1598e-04 - val_mean_squared_error: 6.1598e-04
# Epoch 163/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.6561e-04 - val_mean_squared_error: 6.6561e-04
# Epoch 164/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 6.3207e-04 - val_mean_squared_error: 6.3207e-04
# Epoch 165/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.1129e-04 - val_mean_squared_error: 6.1129e-04
# Epoch 166/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.2416e-04 - val_mean_squared_error: 6.2416e-04
# Epoch 167/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.1142e-04 - val_mean_squared_error: 6.1142e-04
# Epoch 168/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.2626e-04 - val_mean_squared_error: 6.2626e-04
# Epoch 169/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.1154e-04 - val_mean_squared_error: 6.1154e-04
# Epoch 170/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.6517e-04 - val_mean_squared_error: 6.6517e-04
# Epoch 171/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 6.1715e-04 - val_mean_squared_error: 6.1715e-04
# Epoch 172/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.0802e-04 - val_mean_squared_error: 6.0802e-04
# Epoch 173/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1760e-04 - val_mean_squared_error: 6.1760e-04
# Epoch 174/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.2809e-04 - val_mean_squared_error: 6.2809e-04
# Epoch 175/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.2626e-04 - val_mean_squared_error: 6.2626e-04
# Epoch 176/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.3075e-04 - val_mean_squared_error: 6.3075e-04
# Epoch 177/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.3644e-04 - val_mean_squared_error: 6.3644e-04
# Epoch 178/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.1342e-04 - val_mean_squared_error: 6.1342e-04
# Epoch 179/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.2410e-04 - val_mean_squared_error: 6.2410e-04
# Epoch 180/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.2152e-04 - val_mean_squared_error: 6.2152e-04
# Epoch 181/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.0581e-04 - val_mean_squared_error: 6.0581e-04
# Epoch 182/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.0743e-04 - val_mean_squared_error: 6.0743e-04
# Epoch 183/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.6265e-04 - val_mean_squared_error: 6.6265e-04
# Epoch 184/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.2956e-04 - val_mean_squared_error: 6.2956e-04
# Epoch 185/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.0905e-04 - val_mean_squared_error: 6.0905e-04
# Epoch 186/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.4183e-04 - val_mean_squared_error: 6.4183e-04
# Epoch 187/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.0659e-04 - val_mean_squared_error: 6.0659e-04
# Epoch 188/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.1850e-04 - val_mean_squared_error: 6.1850e-04
# Epoch 189/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.3870e-04 - val_mean_squared_error: 6.3870e-04
# Epoch 190/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.4469e-04 - val_mean_squared_error: 6.4469e-04
# Epoch 191/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.0768e-04 - val_mean_squared_error: 6.0768e-04
# Epoch 192/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 6.4794e-04 - val_mean_squared_error: 6.4794e-04
# Epoch 193/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.0583e-04 - val_mean_squared_error: 6.0583e-04
# Epoch 194/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.1149e-04 - val_mean_squared_error: 6.1149e-04
# Epoch 195/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.6173e-04 - val_mean_squared_error: 6.6173e-04
# Epoch 196/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.1184e-04 - val_mean_squared_error: 6.1184e-04
# Epoch 197/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.1159e-04 - val_mean_squared_error: 6.1159e-04
# Epoch 198/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.9043e-04 - val_mean_squared_error: 6.9043e-04
# Epoch 199/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.1204e-04 - val_mean_squared_error: 6.1204e-04
# Epoch 200/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.1880e-04 - val_mean_squared_error: 6.1880e-04
# Epoch 201/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.0567e-04 - val_mean_squared_error: 6.0567e-04
# Epoch 202/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.3321e-04 - val_mean_squared_error: 6.3321e-04
# Epoch 203/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.6746e-04 - val_mean_squared_error: 6.6746e-04
# Epoch 204/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.1644e-04 - val_mean_squared_error: 6.1644e-04
# Epoch 205/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.0165e-04 - val_mean_squared_error: 6.0165e-04
# Epoch 206/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.0924e-04 - val_mean_squared_error: 6.0924e-04
# Epoch 207/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.0485e-04 - val_mean_squared_error: 6.0485e-04
# Epoch 208/300
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.0376e-04 - val_mean_squared_error: 6.0376e-04
# Epoch 209/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.0349e-04 - val_mean_squared_error: 6.0349e-04
# Epoch 210/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.2410e-04 - val_mean_squared_error: 6.2410e-04
# Epoch 211/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.1571e-04 - val_mean_squared_error: 6.1571e-04
# Epoch 212/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.1067e-04 - val_mean_squared_error: 6.1067e-04
# Epoch 213/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.0824e-04 - val_mean_squared_error: 6.0824e-04
# Epoch 214/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0536e-04 - val_mean_squared_error: 6.0536e-04
# Epoch 215/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0212e-04 - val_mean_squared_error: 6.0212e-04
# Epoch 216/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 6.1145e-04 - val_mean_squared_error: 6.1145e-04
# Epoch 217/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.4006e-04 - val_mean_squared_error: 6.4006e-04
# Epoch 218/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.1578e-04 - val_mean_squared_error: 6.1578e-04
# Epoch 219/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.5657e-04 - val_mean_squared_error: 6.5657e-04
# Epoch 220/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 6.2552e-04 - val_mean_squared_error: 6.2552e-04
# Epoch 221/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 6.0654e-04 - val_mean_squared_error: 6.0654e-04
# Epoch 222/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.0191e-04 - val_mean_squared_error: 6.0191e-04
# Epoch 223/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.9939e-04 - val_mean_squared_error: 5.9939e-04
# Epoch 224/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.0963e-04 - val_mean_squared_error: 6.0963e-04
# Epoch 225/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.0343e-04 - val_mean_squared_error: 6.0343e-04
# Epoch 226/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.3292e-04 - val_mean_squared_error: 6.3292e-04
# Epoch 227/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.0211e-04 - val_mean_squared_error: 6.0211e-04
# Epoch 228/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 6.0722e-04 - val_mean_squared_error: 6.0722e-04
# Epoch 229/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 5.9885e-04 - val_mean_squared_error: 5.9885e-04
# Epoch 230/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.4187e-04 - val_mean_squared_error: 6.4187e-04
# Epoch 231/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.0479e-04 - val_mean_squared_error: 6.0479e-04
# Epoch 232/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.6971e-04 - val_mean_squared_error: 6.6971e-04
# Epoch 233/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.2121e-04 - val_mean_squared_error: 6.2121e-04
# Epoch 234/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0201e-04 - val_mean_squared_error: 6.0201e-04
# Epoch 235/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.0121e-04 - val_mean_squared_error: 6.0121e-04
# Epoch 236/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.1077e-04 - val_mean_squared_error: 6.1077e-04
# Epoch 237/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.0193e-04 - val_mean_squared_error: 6.0193e-04
# Epoch 238/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 6.0322e-04 - val_mean_squared_error: 6.0322e-04
# Epoch 239/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.2712e-04 - val_mean_squared_error: 6.2712e-04
# Epoch 240/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.9981e-04 - val_mean_squared_error: 5.9981e-04
# Epoch 241/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 5.9730e-04 - val_mean_squared_error: 5.9730e-04
# Epoch 242/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.9877e-04 - val_mean_squared_error: 5.9877e-04
# Epoch 243/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0517e-04 - val_mean_squared_error: 6.0517e-04
# Epoch 244/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1584e-04 - val_mean_squared_error: 6.1584e-04
# Epoch 245/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 5.9926e-04 - val_mean_squared_error: 5.9926e-04
# Epoch 246/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.7091e-04 - val_mean_squared_error: 6.7091e-04
# Epoch 247/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.1629e-04 - val_mean_squared_error: 6.1629e-04
# Epoch 248/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 7.0755e-04 - val_mean_squared_error: 7.0755e-04
# Epoch 249/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 6.1553e-04 - val_mean_squared_error: 6.1553e-04
# Epoch 250/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.0947e-04 - val_mean_squared_error: 6.0947e-04
# Epoch 251/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 5.9848e-04 - val_mean_squared_error: 5.9848e-04
# Epoch 252/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 6.0711e-04 - val_mean_squared_error: 6.0711e-04
# Epoch 253/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0879e-04 - val_mean_squared_error: 6.0879e-04
# Epoch 254/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 5.9490e-04 - val_mean_squared_error: 5.9490e-04
# Epoch 255/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.2555e-04 - val_mean_squared_error: 6.2555e-04
# Epoch 256/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 6.0815e-04 - val_mean_squared_error: 6.0815e-04
# Epoch 257/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.0260e-04 - val_mean_squared_error: 6.0260e-04
# Epoch 258/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 6.0686e-04 - val_mean_squared_error: 6.0686e-04
# Epoch 259/300
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.9779e-04 - val_mean_squared_error: 5.9779e-04
# Epoch 260/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 6.0865e-04 - val_mean_squared_error: 6.0865e-04
# Epoch 261/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.0743e-04 - val_mean_squared_error: 6.0743e-04
# Epoch 262/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.1984e-04 - val_mean_squared_error: 6.1984e-04
# Epoch 263/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 6.1177e-04 - val_mean_squared_error: 6.1177e-04
# Epoch 264/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 6.4800e-04 - val_mean_squared_error: 6.4800e-04
# Epoch 265/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.0132e-04 - val_mean_squared_error: 6.0132e-04
# Epoch 266/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.0055e-04 - val_mean_squared_error: 6.0055e-04
# Epoch 267/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.0215e-04 - val_mean_squared_error: 6.0215e-04
# Epoch 268/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 6.1205e-04 - val_mean_squared_error: 6.1205e-04
# Epoch 269/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 5.9408e-04 - val_mean_squared_error: 5.9408e-04
# Epoch 270/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.1418e-04 - val_mean_squared_error: 6.1418e-04
# Epoch 271/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 5.9492e-04 - val_mean_squared_error: 5.9492e-04
# Epoch 272/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 5.9851e-04 - val_mean_squared_error: 5.9851e-04
# Epoch 273/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.2362e-04 - val_mean_squared_error: 6.2362e-04
# Epoch 274/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.0580e-04 - val_mean_squared_error: 6.0580e-04
# Epoch 275/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 5.9238e-04 - val_mean_squared_error: 5.9238e-04
# Epoch 276/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 6.2514e-04 - val_mean_squared_error: 6.2514e-04
# Epoch 277/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 5.9852e-04 - val_mean_squared_error: 5.9852e-04
# Epoch 278/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.0854e-04 - val_mean_squared_error: 6.0854e-04
# Epoch 279/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 5.9273e-04 - val_mean_squared_error: 5.9273e-04
# Epoch 280/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 7.0881e-04 - val_mean_squared_error: 7.0881e-04
# Epoch 281/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 6.0649e-04 - val_mean_squared_error: 6.0649e-04
# Epoch 282/300
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 7.4900e-04 - val_mean_squared_error: 7.4900e-04
# Epoch 283/300
# 17/17 [==============================] - 0s 28ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.1291e-04 - val_mean_squared_error: 6.1291e-04
# Epoch 284/300
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.9269e-04 - val_mean_squared_error: 5.9269e-04
# Epoch 285/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.9943e-04 - val_mean_squared_error: 5.9943e-04
# Epoch 286/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 5.9028e-04 - val_mean_squared_error: 5.9028e-04
# Epoch 287/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 6.3113e-04 - val_mean_squared_error: 6.3113e-04
# Epoch 288/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.9993e-04 - val_mean_squared_error: 5.9993e-04
# Epoch 289/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 5.9790e-04 - val_mean_squared_error: 5.9790e-04
# Epoch 290/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.0267e-04 - val_mean_squared_error: 6.0267e-04
# Epoch 291/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 5.9733e-04 - val_mean_squared_error: 5.9733e-04
# Epoch 292/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 5.9188e-04 - val_mean_squared_error: 5.9188e-04
# Epoch 293/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.9045e-04 - val_mean_squared_error: 5.9045e-04
# Epoch 294/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 5.9146e-04 - val_mean_squared_error: 5.9146e-04
# Epoch 295/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 6.1220e-04 - val_mean_squared_error: 6.1220e-04
# Epoch 296/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 6.3352e-04 - val_mean_squared_error: 6.3352e-04
# Epoch 297/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 6.1129e-04 - val_mean_squared_error: 6.1129e-04
# Epoch 298/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.8999e-04 - val_mean_squared_error: 5.8999e-04
# Epoch 299/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 7.4476e-04 - val_mean_squared_error: 7.4476e-04
# Epoch 300/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.9380e-04 - val_mean_squared_error: 5.9380e-04

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 2s 4ms/step
# 10/10 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# (1044, 1) (294, 1) (144, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1044,) (294,) (144,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[0.06556252]
#  [0.06864271]
#  [0.07008003]
#  [0.06993237]
#  [0.07066206]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.062]
#  [0.067]
#  [0.066]
#  [0.071]
#  [0.072]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))
# Out:
# Train Mean Squared Error: 0.10941977031712685
# Test Mean Squared Error: 0.07171489197054305
# Val Mean Squared Error: 0.02115815812181712
# Train Score: 0.11 RMSE
# Test Score: 0.07 RMSE
# Val Score: 0.02 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 12.998391571710327
# Test Mean Absolute Percentage Error: 6.331293183585261
# Val Mean Absolute Percentage Error: 4.805094518971072
# Train Score: 13.00 MAPE
# Test Score: 6.33 MAPE
# Val Score: 4.81 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (5, 1)
# -----------------
# day  1  have input =  [0.114509   0.1114509  0.11314985 0.10941216 0.11043153]
# day  1  have output =  0.11057046
# -----------------
# day  2  have input =  [0.1114509  0.11314985 0.10941216 0.11043153 0.11057046]
# day  2  have output =  0.10935213
# -----------------
# day  3  have input =  [0.11314985 0.10941216 0.11043153 0.11057046 0.10935213]
# day  3  have output =  0.109096274
# -----------------
# day  4  have input =  [0.10941216 0.11043153 0.11057046 0.10935213 0.10909627]
# day  4  have output =  0.107920706
# -----------------
# day  5  have input =  [0.11043153 0.11057046 0.10935213 0.10909627 0.10792071]
# day  5  have output =  0.108026005
# -----------------
# day  6  have input =  [0.11057046 0.10935213 0.10909627 0.10792071 0.10802601]
# day  6  have output =  0.10757586
# -----------------
# day  7  have input =  [0.10935213 0.10909627 0.10792071 0.10802601 0.10757586]
# day  7  have output =  0.10684272
# -----------------
# day  8  have input =  [0.10909627 0.10792071 0.10802601 0.10757586 0.10684272]
# day  8  have output =  0.10637319
# -----------------
# day  9  have input =  [0.10792071 0.10802601 0.10757586 0.10684272 0.10637319]
# day  9  have output =  0.10580114
# -----------------
# day  10  have input =  [0.10802601 0.10757586 0.10684272 0.10637319 0.10580114]
# day  10  have output =  0.10550818
# -----------------
# day  11  have input =  [0.10757586 0.10684272 0.10637319 0.10580114 0.10550818]
# day  11  have output =  0.104987375
# -----------------
# day  12  have input =  [0.10684272 0.10637319 0.10580114 0.10550818 0.10498738]
# day  12  have output =  0.10443838
# -----------------
# day  13  have input =  [0.10637319 0.10580114 0.10550818 0.10498738 0.10443838]
# day  13  have output =  0.10398314
# -----------------
# day  14  have input =  [0.10580114 0.10550818 0.10498738 0.10443838 0.10398314]
# day  14  have output =  0.10352577
# -----------------
# day  15  have input =  [0.10550818 0.10498738 0.10443838 0.10398314 0.10352577]
# day  15  have output =  0.103110805
# -----------------
# day  16  have input =  [0.10498738 0.10443838 0.10398314 0.10352577 0.10311081]
# day  16  have output =  0.1026252
# -----------------
# day  17  have input =  [0.10443838 0.10398314 0.10352577 0.10311081 0.1026252 ]
# day  17  have output =  0.10215646
# -----------------
# day  18  have input =  [0.10398314 0.10352577 0.10311081 0.1026252  0.10215646]
# day  18  have output =  0.10172203
# -----------------
# day  19  have input =  [0.10352577 0.10311081 0.1026252  0.10215646 0.10172203]
# day  19  have output =  0.10128842
# -----------------
# day  20  have input =  [0.10311081 0.1026252  0.10215646 0.10172203 0.10128842]
# day  20  have output =  0.1008575
# -----------------
# day  21  have input =  [0.1026252  0.10215646 0.10172203 0.10128842 0.1008575 ]
# day  21  have output =  0.10041246
# -----------------
# day  22  have input =  [0.10215646 0.10172203 0.10128842 0.1008575  0.10041246]
# day  22  have output =  0.09998277
# -----------------
# day  23  have input =  [0.10172203 0.10128842 0.1008575  0.10041246 0.09998277]
# day  23  have output =  0.09956528
# -----------------
# day  24  have input =  [0.10128842 0.1008575  0.10041246 0.09998277 0.09956528]
# day  24  have output =  0.09914832
# -----------------
# day  25  have input =  [0.1008575  0.10041246 0.09998277 0.09956528 0.09914832]
# day  25  have output =  0.098732635
# -----------------
# day  26  have input =  [0.10041246 0.09998277 0.09956528 0.09914832 0.09873264]
# day  26  have output =  0.09831849
# -----------------
# day  27  have input =  [0.09998277 0.09956528 0.09914832 0.09873264 0.09831849]
# day  27  have output =  0.09791352
# -----------------
# day  28  have input =  [0.09956528 0.09914832 0.09873264 0.09831849 0.09791352]
# day  28  have output =  0.09751386
# -----------------
# day  29  have input =  [0.09914832 0.09873264 0.09831849 0.09791352 0.09751386]
# day  29  have output =  0.097116224
# -----------------
# day  30  have input =  [0.09873264 0.09831849 0.09791352 0.09751386 0.09711622]
# day  30  have output =  0.09672184

# %%
#in ra 30 ngày tiếp theo
print("Du doan 30 ngay tiep theo: ", lst_output)
# Out:
# Du doan 30 ngay tiep theo:  [0.11057046, 0.10935213, 0.109096274, 0.107920706, 0.108026005, 0.10757586, 0.10684272, 0.10637319, 0.10580114, 0.10550818, 0.104987375, 0.10443838, 0.10398314, 0.10352577, 0.103110805, 0.1026252, 0.10215646, 0.10172203, 0.10128842, 0.1008575, 0.10041246, 0.09998277, 0.09956528, 0.09914832, 0.098732635, 0.09831849, 0.09791352, 0.09751386, 0.097116224, 0.09672184]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.052]
#  [0.058]
#  [0.063]
#  [0.062]
#  [0.059]]
# [[1.319]
#  [1.309]
#  [1.23 ]
#  [1.28 ]
#  [1.21 ]]
# [[0.406]
#  [0.406]
#  [0.401]
#  [0.386]
#  [0.39 ]]
# [[0.34840885]
#  [0.3448233 ]
#  [0.34407032]
#  [0.34061062]
#  [0.34092054]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
