# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/ETHUSDT.xlsx')
df1=df.reset_index()['Close']

plt.plot(df1)

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00575087]
#  [0.00599129]
#  [0.00626787]
#  [0.00601469]
#  [0.00556577]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1046, 3) (1046,) (146, 3) (146,) (296, 3) (296,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00575087]
#   [0.00599129]
#   [0.00626787]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, SimpleRNN #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()
input_shape = (time_step, 1)
model.add(SimpleRNN(64, input_shape=input_shape, return_sequences=True))
model.add(SimpleRNN(32, input_shape=input_shape,return_sequences=True))
model.add(SimpleRNN(16))

model.add(Dense(5))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 17/17 [==============================] - 3s 34ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 2/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 3/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 4/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 5/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 6/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 7/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 9.4416e-04 - val_mean_squared_error: 9.4416e-04
# Epoch 8/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 9.2523e-04 - val_mean_squared_error: 9.2523e-04
# Epoch 9/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 8.7861e-04 - val_mean_squared_error: 8.7861e-04
# Epoch 10/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 11/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 8.2547e-04 - val_mean_squared_error: 8.2547e-04
# Epoch 12/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 13/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 7.3611e-04 - val_mean_squared_error: 7.3611e-04
# Epoch 14/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 9.5417e-04 - val_mean_squared_error: 9.5417e-04
# Epoch 15/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 7.2610e-04 - val_mean_squared_error: 7.2610e-04
# Epoch 16/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 17/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.1396e-04 - val_mean_squared_error: 9.1396e-04
# Epoch 18/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 9.5180e-04 - val_mean_squared_error: 9.5180e-04
# Epoch 19/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 20/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 8.8936e-04 - val_mean_squared_error: 8.8936e-04
# Epoch 21/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 8.7457e-04 - val_mean_squared_error: 8.7457e-04
# Epoch 22/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 8.4608e-04 - val_mean_squared_error: 8.4608e-04
# Epoch 23/300
# 17/17 [==============================] - 0s 28ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 24/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 8.0186e-04 - val_mean_squared_error: 8.0186e-04
# Epoch 25/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 8.1045e-04 - val_mean_squared_error: 8.1045e-04
# Epoch 26/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 7.0173e-04 - val_mean_squared_error: 7.0173e-04
# Epoch 27/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 28/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 8.9630e-04 - val_mean_squared_error: 8.9630e-04
# Epoch 29/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 9.3282e-04 - val_mean_squared_error: 9.3282e-04
# Epoch 30/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 7.2971e-04 - val_mean_squared_error: 7.2971e-04
# Epoch 31/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 8.8201e-04 - val_mean_squared_error: 8.8201e-04
# Epoch 32/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 6.6649e-04 - val_mean_squared_error: 6.6649e-04
# Epoch 33/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 6.6062e-04 - val_mean_squared_error: 6.6062e-04
# Epoch 34/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 8.3828e-04 - val_mean_squared_error: 8.3828e-04
# Epoch 35/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 8.9075e-04 - val_mean_squared_error: 8.9075e-04
# Epoch 36/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 6.4305e-04 - val_mean_squared_error: 6.4305e-04
# Epoch 37/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 38/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.5031e-04 - val_mean_squared_error: 6.5031e-04
# Epoch 39/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 6.4470e-04 - val_mean_squared_error: 6.4470e-04
# Epoch 40/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 6.3697e-04 - val_mean_squared_error: 6.3697e-04
# Epoch 41/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 42/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.4072e-04 - val_mean_squared_error: 6.4072e-04
# Epoch 43/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 44/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 7.8156e-04 - val_mean_squared_error: 7.8156e-04
# Epoch 45/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 7.1730e-04 - val_mean_squared_error: 7.1730e-04
# Epoch 46/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 7.5681e-04 - val_mean_squared_error: 7.5681e-04
# Epoch 47/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.6249e-04 - val_mean_squared_error: 6.6249e-04
# Epoch 48/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 6.2620e-04 - val_mean_squared_error: 6.2620e-04
# Epoch 49/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 8.4038e-04 - val_mean_squared_error: 8.4038e-04
# Epoch 50/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 7.9647e-04 - val_mean_squared_error: 7.9647e-04
# Epoch 51/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 7.8939e-04 - val_mean_squared_error: 7.8939e-04
# Epoch 52/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 53/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 8.5211e-04 - val_mean_squared_error: 8.5211e-04
# Epoch 54/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 6.8583e-04 - val_mean_squared_error: 6.8583e-04
# Epoch 55/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 6.2556e-04 - val_mean_squared_error: 6.2556e-04
# Epoch 56/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.1150e-04 - val_mean_squared_error: 6.1150e-04
# Epoch 57/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 6.8195e-04 - val_mean_squared_error: 6.8195e-04
# Epoch 58/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 59/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 60/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 6.1387e-04 - val_mean_squared_error: 6.1387e-04
# Epoch 61/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 7.5617e-04 - val_mean_squared_error: 7.5617e-04
# Epoch 62/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 8.5776e-04 - val_mean_squared_error: 8.5776e-04
# Epoch 63/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 64/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 6.6715e-04 - val_mean_squared_error: 6.6715e-04
# Epoch 65/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 6.3878e-04 - val_mean_squared_error: 6.3878e-04
# Epoch 66/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 5.9920e-04 - val_mean_squared_error: 5.9920e-04
# Epoch 67/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 68/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 69/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 6.0611e-04 - val_mean_squared_error: 6.0611e-04
# Epoch 70/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 71/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 7.3249e-04 - val_mean_squared_error: 7.3249e-04
# Epoch 72/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 6.5167e-04 - val_mean_squared_error: 6.5167e-04
# Epoch 73/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 8.8081e-04 - val_mean_squared_error: 8.8081e-04
# Epoch 74/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 75/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 76/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 77/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.7961e-04 - val_mean_squared_error: 5.7961e-04
# Epoch 78/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 79/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 5.9680e-04 - val_mean_squared_error: 5.9680e-04
# Epoch 80/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 8.1818e-04 - val_mean_squared_error: 8.1818e-04
# Epoch 81/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.8452e-04 - val_mean_squared_error: 6.8452e-04
# Epoch 82/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 83/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 6.2632e-04 - val_mean_squared_error: 6.2632e-04
# Epoch 84/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 8.4114e-04 - val_mean_squared_error: 8.4114e-04
# Epoch 85/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 86/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 5.8048e-04 - val_mean_squared_error: 5.8048e-04
# Epoch 87/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 88/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 89/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 8.4399e-04 - val_mean_squared_error: 8.4399e-04
# Epoch 90/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 9.4709e-04 - val_mean_squared_error: 9.4709e-04
# Epoch 91/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 5.8428e-04 - val_mean_squared_error: 5.8428e-04
# Epoch 92/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.9703e-04 - val_mean_squared_error: 6.9703e-04
# Epoch 93/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 94/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 95/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 96/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 5.6060e-04 - val_mean_squared_error: 5.6060e-04
# Epoch 97/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 5.6144e-04 - val_mean_squared_error: 5.6144e-04
# Epoch 98/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 5.6225e-04 - val_mean_squared_error: 5.6225e-04
# Epoch 99/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 7.3753e-04 - val_mean_squared_error: 7.3753e-04
# Epoch 100/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 5.8103e-04 - val_mean_squared_error: 5.8103e-04
# Epoch 101/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.9932e-04 - val_mean_squared_error: 6.9932e-04
# Epoch 102/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 5.5736e-04 - val_mean_squared_error: 5.5736e-04
# Epoch 103/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 7.5415e-04 - val_mean_squared_error: 7.5415e-04
# Epoch 104/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 105/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.7954e-04 - val_mean_squared_error: 8.7954e-04
# Epoch 106/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 8.0256e-04 - val_mean_squared_error: 8.0256e-04
# Epoch 107/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 108/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 109/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 5.5011e-04 - val_mean_squared_error: 5.5011e-04
# Epoch 110/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 5.5720e-04 - val_mean_squared_error: 5.5720e-04
# Epoch 111/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1277e-04 - val_mean_squared_error: 6.1277e-04
# Epoch 112/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 8.2433e-04 - val_mean_squared_error: 8.2433e-04
# Epoch 113/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 114/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.9211e-04 - val_mean_squared_error: 6.9211e-04
# Epoch 115/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 8.2553e-04 - val_mean_squared_error: 8.2553e-04
# Epoch 116/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 117/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.2601e-04 - val_mean_squared_error: 6.2601e-04
# Epoch 118/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 5.4182e-04 - val_mean_squared_error: 5.4182e-04
# Epoch 119/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 5.4767e-04 - val_mean_squared_error: 5.4767e-04
# Epoch 120/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 121/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 122/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 6.4357e-04 - val_mean_squared_error: 6.4357e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 7.0910e-04 - val_mean_squared_error: 7.0910e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.1248e-04 - val_mean_squared_error: 6.1248e-04
# Epoch 125/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 5.3444e-04 - val_mean_squared_error: 5.3444e-04
# Epoch 126/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.5504e-04 - val_mean_squared_error: 6.5504e-04
# Epoch 127/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 5.4482e-04 - val_mean_squared_error: 5.4482e-04
# Epoch 128/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.4413e-04 - val_mean_squared_error: 5.4413e-04
# Epoch 129/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 6.9804e-04 - val_mean_squared_error: 6.9804e-04
# Epoch 130/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 8.1581e-04 - val_mean_squared_error: 8.1581e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 5.3820e-04 - val_mean_squared_error: 5.3820e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 5.3621e-04 - val_mean_squared_error: 5.3621e-04
# Epoch 133/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 5.9013e-04 - val_mean_squared_error: 5.9013e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 5.4597e-04 - val_mean_squared_error: 5.4597e-04
# Epoch 135/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 5.2758e-04 - val_mean_squared_error: 5.2758e-04
# Epoch 136/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 137/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 138/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.0500e-04 - val_mean_squared_error: 8.0500e-04
# Epoch 139/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 5.3782e-04 - val_mean_squared_error: 5.3782e-04
# Epoch 140/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 5.2614e-04 - val_mean_squared_error: 5.2614e-04
# Epoch 141/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 142/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 143/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.6176e-04 - val_mean_squared_error: 6.6176e-04
# Epoch 144/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 145/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 9.5782e-04 - val_mean_squared_error: 9.5782e-04
# Epoch 146/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 147/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 5.2588e-04 - val_mean_squared_error: 5.2588e-04
# Epoch 148/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 5.2042e-04 - val_mean_squared_error: 5.2042e-04
# Epoch 149/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 5.1267e-04 - val_mean_squared_error: 5.1267e-04
# Epoch 150/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 5.7610e-04 - val_mean_squared_error: 5.7610e-04
# Epoch 151/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 5.5525e-04 - val_mean_squared_error: 5.5525e-04
# Epoch 152/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 8.5837e-04 - val_mean_squared_error: 8.5837e-04
# Epoch 153/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 5.1302e-04 - val_mean_squared_error: 5.1302e-04
# Epoch 154/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 5.6929e-04 - val_mean_squared_error: 5.6929e-04
# Epoch 155/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.1157e-04 - val_mean_squared_error: 5.1157e-04
# Epoch 156/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 5.4624e-04 - val_mean_squared_error: 5.4624e-04
# Epoch 157/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 5.1376e-04 - val_mean_squared_error: 5.1376e-04
# Epoch 158/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 6.4050e-04 - val_mean_squared_error: 6.4050e-04
# Epoch 159/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.8033e-04 - val_mean_squared_error: 6.8033e-04
# Epoch 160/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 6.2557e-04 - val_mean_squared_error: 6.2557e-04
# Epoch 161/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 5.1908e-04 - val_mean_squared_error: 5.1908e-04
# Epoch 162/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 5.7676e-04 - val_mean_squared_error: 5.7676e-04
# Epoch 163/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.1362e-04 - val_mean_squared_error: 5.1362e-04
# Epoch 164/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 5.4547e-04 - val_mean_squared_error: 5.4547e-04
# Epoch 165/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 8.4682e-04 - val_mean_squared_error: 8.4682e-04
# Epoch 166/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.5541e-04 - val_mean_squared_error: 6.5541e-04
# Epoch 167/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 5.2020e-04 - val_mean_squared_error: 5.2020e-04
# Epoch 168/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 6.0356e-04 - val_mean_squared_error: 6.0356e-04
# Epoch 169/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 170/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 171/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 172/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 173/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 8.0452e-04 - val_mean_squared_error: 8.0452e-04
# Epoch 174/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 6.2223e-04 - val_mean_squared_error: 6.2223e-04
# Epoch 175/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 7.5836e-04 - val_mean_squared_error: 7.5836e-04
# Epoch 176/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 6.2866e-04 - val_mean_squared_error: 6.2866e-04
# Epoch 177/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 5.9501e-04 - val_mean_squared_error: 5.9501e-04
# Epoch 178/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 6.3993e-04 - val_mean_squared_error: 6.3993e-04
# Epoch 179/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 6.4242e-04 - val_mean_squared_error: 6.4242e-04
# Epoch 180/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.3819e-04 - val_mean_squared_error: 5.3819e-04
# Epoch 180: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 1s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1046, 1) (296, 1) (146, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1046,) (296,) (146,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[175.29964]
#  [175.14058]
#  [173.4108 ]
#  [172.67392]
#  [175.7913 ]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[136.09]
#  [133.98]
#  [134.18]
#  [139.45]
#  [137.86]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE 
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))

#tinh mae va rmse chung
# Out:
# Train Mean Squared Error: 128.19769887012
# Test Mean Squared Error: 109.03858043149042
# Val Mean Squared Error: 58.711390549130876
# Train Score: 128.20 RMSE
# Test Score: 109.04 RMSE
# Val Score: 58.71 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 11.925646251703656
# Test Mean Absolute Percentage Error: 3.8392913417501817
# Val Mean Absolute Percentage Error: 2.7355913867059405
# Train Score: 11.93 MAPE
# Test Score: 3.84 MAPE
# Val Score: 2.74 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.35446878 0.34198836 0.34230537]
# day  1  have output =  0.33872393
# -----------------
# day  2  have input =  [0.34198836 0.34230537 0.33872393]
# day  2  have output =  0.33668357
# -----------------
# day  3  have input =  [0.34230537 0.33872393 0.33668357]
# day  3  have output =  0.334106
# -----------------
# day  4  have input =  [0.33872393 0.33668357 0.334106  ]
# day  4  have output =  0.3318048
# -----------------
# day  5  have input =  [0.33668357 0.334106   0.33180481]
# day  5  have output =  0.32945818
# -----------------
# day  6  have input =  [0.334106   0.33180481 0.32945818]
# day  6  have output =  0.32719207
# -----------------
# day  7  have input =  [0.33180481 0.32945818 0.32719207]
# day  7  have output =  0.3249551
# -----------------
# day  8  have input =  [0.32945818 0.32719207 0.32495511]
# day  8  have output =  0.32276672
# -----------------
# day  9  have input =  [0.32719207 0.32495511 0.32276672]
# day  9  have output =  0.32061803
# -----------------
# day  10  have input =  [0.32495511 0.32276672 0.32061803]
# day  10  have output =  0.31851137
# -----------------
# day  11  have input =  [0.32276672 0.32061803 0.31851137]
# day  11  have output =  0.3164448
# -----------------
# day  12  have input =  [0.32061803 0.31851137 0.31644481]
# day  12  have output =  0.31441778
# -----------------
# day  13  have input =  [0.31851137 0.31644481 0.31441778]
# day  13  have output =  0.3124298
# -----------------
# day  14  have input =  [0.31644481 0.31441778 0.31242979]
# day  14  have output =  0.31047988
# -----------------
# day  15  have input =  [0.31441778 0.31242979 0.31047988]
# day  15  have output =  0.30856743
# -----------------
# day  16  have input =  [0.31242979 0.31047988 0.30856743]
# day  16  have output =  0.30669165
# -----------------
# day  17  have input =  [0.31047988 0.30856743 0.30669165]
# day  17  have output =  0.3048521
# -----------------
# day  18  have input =  [0.30856743 0.30669165 0.3048521 ]
# day  18  have output =  0.30304784
# -----------------
# day  19  have input =  [0.30669165 0.3048521  0.30304784]
# day  19  have output =  0.30127853
# -----------------
# day  20  have input =  [0.3048521  0.30304784 0.30127853]
# day  20  have output =  0.29954302
# -----------------
# day  21  have input =  [0.30304784 0.30127853 0.29954302]
# day  21  have output =  0.29784107
# -----------------
# day  22  have input =  [0.30127853 0.29954302 0.29784107]
# day  22  have output =  0.29617214
# -----------------
# day  23  have input =  [0.29954302 0.29784107 0.29617214]
# day  23  have output =  0.29453546
# -----------------
# day  24  have input =  [0.29784107 0.29617214 0.29453546]
# day  24  have output =  0.29293045
# -----------------
# day  25  have input =  [0.29617214 0.29453546 0.29293045]
# day  25  have output =  0.29135668
# -----------------
# day  26  have input =  [0.29453546 0.29293045 0.29135668]
# day  26  have output =  0.2898133
# -----------------
# day  27  have input =  [0.29293045 0.29135668 0.28981331]
# day  27  have output =  0.28829986
# -----------------
# day  28  have input =  [0.29135668 0.28981331 0.28829986]
# day  28  have output =  0.28681624
# -----------------
# day  29  have input =  [0.28981331 0.28829986 0.28681624]
# day  29  have output =  0.28536123
# -----------------
# day  30  have input =  [0.28829986 0.28681624 0.28536123]
# day  30  have output =  0.2839347

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.33872393, 0.33668357, 0.334106, 0.3318048, 0.32945818, 0.32719207, 0.3249551, 0.32276672, 0.32061803, 0.31851137, 0.3164448, 0.31441778, 0.3124298, 0.31047988, 0.30856743, 0.30669165, 0.3048521, 0.30304784, 0.30127853, 0.29954302, 0.29784107, 0.29617214, 0.29453546, 0.29293045, 0.29135668, 0.2898133, 0.28829986, 0.28681624, 0.28536123, 0.2839347]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[134.85]
#  [135.98]
#  [137.28]
#  [136.09]
#  [133.98]]
# [[3765.89]
#  [3785.11]
#  [3540.63]
#  [3406.81]
#  [3199.24]]
# [[1590.44]
#  [1572.69]
#  [1578.48]
#  [1518.34]
#  [1531.01]]
# [[1699.8767]
#  [1690.2867]
#  [1678.1716]
#  [1667.3557]
#  [1656.3262]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
