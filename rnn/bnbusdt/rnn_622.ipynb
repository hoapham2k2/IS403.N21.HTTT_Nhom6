# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/BNBUSDT.xlsx')
df1=df.reset_index()['Close']

plt.plot(df1)

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.6 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (900, 1) (300, 1) (300, 1)
# [[0.00763841]
#  [0.0088365 ]
#  [0.00882151]
#  [0.0117755 ]
#  [0.01125518]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (896, 3) (896,) (296, 3) (296,) (296, 3) (296,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (896, 3, 1) (296, 3, 1) (296, 3, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00763841]
#   [0.0088365 ]
#   [0.00882151]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, SimpleRNN #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(SimpleRNN(64, input_shape=input_shape, return_sequences=True))
model.add(SimpleRNN(32, input_shape=input_shape,return_sequences=True))
model.add(SimpleRNN(16))

model.add(Dense(5))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (896, 3, 1) (296, 3, 1) (296, 3, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 14/14 [==============================] - 4s 36ms/step - loss: 0.0597 - mean_squared_error: 0.0597 - val_loss: 0.0778 - val_mean_squared_error: 0.0778
# Epoch 2/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 3/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 4/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 5/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 6/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 7/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 8/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 9/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 10/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 11/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 12/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 13/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 14/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 15/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 16/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 17/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 18/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 19/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 20/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 21/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 22/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 23/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 24/300
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 25/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 26/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 27/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 28/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 29/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 31/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 32/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 33/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 34/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 35/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 36/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 37/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 38/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 39/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 40/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 41/300
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 42/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 43/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 44/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 45/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 46/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 47/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 48/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 49/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 50/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 51/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 52/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 53/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 54/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 55/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 56/300
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 57/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 58/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 59/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 60/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 61/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 62/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 63/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 64/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 65/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 66/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 67/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 68/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 69/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 70/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 71/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 72/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 73/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 74/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 75/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 76/300
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 77/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 78/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 79/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 80/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 81/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 82/300
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 83/300
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 84/300
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 85/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 86/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 87/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 88/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 89/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 90/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 91/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 92/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 93/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 94/300
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 95/300
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 96/300
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 97/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 98/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 99/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 100/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 101/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 102/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 103/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 104/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 105/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 106/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 107/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 108/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 109/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 110/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 111/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 112/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 113/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 114/300
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 115/300
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 116/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 117/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 118/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 119/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 120/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 121/300
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 122/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 123/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 124/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 125/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 126/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 127/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 128/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 129/300
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 130/300
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 131/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 131: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 28/28 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# (896, 1) (296, 1) (296, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (896,) (296,) (296,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[18.216429]
#  [19.570366]
#  [19.80187 ]
#  [19.46784 ]
#  [19.579803]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[17.11 ]
#  [16.763]
#  [16.2  ]
#  [16.6  ]
#  [16.666]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))
# Out:
# Train Mean Squared Error: 16.87796804081541
# Test Mean Squared Error: 31.648114717899027
# Val Mean Squared Error: 10.55688297768349
# Train Score: 16.88 RMSE
# Test Score: 31.65 RMSE
# Val Score: 10.56 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 12.174985229656306
# Test Mean Absolute Percentage Error: 4.893231923875007
# Val Mean Absolute Percentage Error: 2.7355817463316665
# Train Score: 12.17 MAPE
# Test Score: 4.89 MAPE
# Val Score: 2.74 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.47885193 0.45186109 0.45291074]
# day  1  have output =  0.44659707
# -----------------
# day  2  have input =  [0.45186109 0.45291074 0.44659707]
# day  2  have output =  0.44162038
# -----------------
# day  3  have input =  [0.45291074 0.44659707 0.44162038]
# day  3  have output =  0.436797
# -----------------
# day  4  have input =  [0.44659707 0.44162038 0.43679699]
# day  4  have output =  0.43199423
# -----------------
# day  5  have input =  [0.44162038 0.43679699 0.43199423]
# day  5  have output =  0.42733225
# -----------------
# day  6  have input =  [0.43679699 0.43199423 0.42733225]
# day  6  have output =  0.42276448
# -----------------
# day  7  have input =  [0.43199423 0.42733225 0.42276448]
# day  7  have output =  0.4182936
# -----------------
# day  8  have input =  [0.42733225 0.42276448 0.4182936 ]
# day  8  have output =  0.4139146
# -----------------
# day  9  have input =  [0.42276448 0.4182936  0.41391459]
# day  9  have output =  0.40962246
# -----------------
# day  10  have input =  [0.4182936  0.41391459 0.40962246]
# day  10  have output =  0.40541324
# -----------------
# day  11  have input =  [0.41391459 0.40962246 0.40541324]
# day  11  have output =  0.40128344
# -----------------
# day  12  have input =  [0.40962246 0.40541324 0.40128344]
# day  12  have output =  0.39722967
# -----------------
# day  13  have input =  [0.40541324 0.40128344 0.39722967]
# day  13  have output =  0.39324808
# -----------------
# day  14  have input =  [0.40128344 0.39722967 0.39324808]
# day  14  have output =  0.38933608
# -----------------
# day  15  have input =  [0.39722967 0.39324808 0.38933608]
# day  15  have output =  0.3854911
# -----------------
# day  16  have input =  [0.39324808 0.38933608 0.3854911 ]
# day  16  have output =  0.38171044
# -----------------
# day  17  have input =  [0.38933608 0.3854911  0.38171044]
# day  17  have output =  0.37799165
# -----------------
# day  18  have input =  [0.3854911  0.38171044 0.37799165]
# day  18  have output =  0.37433222
# -----------------
# day  19  have input =  [0.38171044 0.37799165 0.37433222]
# day  19  have output =  0.37073058
# -----------------
# day  20  have input =  [0.37799165 0.37433222 0.37073058]
# day  20  have output =  0.36718455
# -----------------
# day  21  have input =  [0.37433222 0.37073058 0.36718455]
# day  21  have output =  0.3636921
# -----------------
# day  22  have input =  [0.37073058 0.36718455 0.3636921 ]
# day  22  have output =  0.36025175
# -----------------
# day  23  have input =  [0.36718455 0.3636921  0.36025175]
# day  23  have output =  0.35686207
# -----------------
# day  24  have input =  [0.3636921  0.36025175 0.35686207]
# day  24  have output =  0.35352144
# -----------------
# day  25  have input =  [0.36025175 0.35686207 0.35352144]
# day  25  have output =  0.35022828
# -----------------
# day  26  have input =  [0.35686207 0.35352144 0.35022828]
# day  26  have output =  0.3469817
# -----------------
# day  27  have input =  [0.35352144 0.35022828 0.3469817 ]
# day  27  have output =  0.3437803
# -----------------
# day  28  have input =  [0.35022828 0.3469817  0.34378031]
# day  28  have output =  0.34062308
# -----------------
# day  29  have input =  [0.3469817  0.34378031 0.34062308]
# day  29  have output =  0.33750877
# -----------------
# day  30  have input =  [0.34378031 0.34062308 0.33750877]
# day  30  have output =  0.3344367

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.44659707, 0.44162038, 0.436797, 0.43199423, 0.42733225, 0.42276448, 0.4182936, 0.4139146, 0.40962246, 0.40541324, 0.40128344, 0.39722967, 0.39324808, 0.38933608, 0.3854911, 0.38171044, 0.37799165, 0.37433222, 0.37073058, 0.36718455, 0.3636921, 0.36025175, 0.35686207, 0.35352144, 0.35022828, 0.3469817, 0.3437803, 0.34062308, 0.33750877, 0.3344367]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[14.351]
#  [15.15 ]
#  [15.14 ]
#  [17.11 ]
#  [16.763]]
# [[496.1]
#  [418.7]
#  [415. ]
#  [421.3]
#  [401.4]]
# [[308.3]
#  [298.6]
#  [301.3]
#  [299.1]
#  [295.1]]
# [[307.08945]
#  [303.77054]
#  [300.55386]
#  [297.35092]
#  [294.24188]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
