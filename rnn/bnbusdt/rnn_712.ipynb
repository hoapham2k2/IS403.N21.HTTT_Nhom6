# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/BNBUSDT.xlsx')
df1=df.reset_index()['Close']

plt.plot(df1)

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00763841]
#  [0.0088365 ]
#  [0.00882151]
#  [0.0117755 ]
#  [0.01125518]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1046, 3) (1046,) (146, 3) (146,) (296, 3) (296,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00763841]
#   [0.0088365 ]
#   [0.00882151]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, SimpleRNN #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()
input_shape = (time_step, 1)
model.add(SimpleRNN(64, input_shape=input_shape, return_sequences=True))
model.add(SimpleRNN(32, input_shape=input_shape,return_sequences=True))
model.add(SimpleRNN(16))

model.add(Dense(5))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 17/17 [==============================] - 4s 42ms/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 7.6957e-04 - val_mean_squared_error: 7.6957e-04
# Epoch 2/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 3/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 4/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 7.0212e-04 - val_mean_squared_error: 7.0212e-04
# Epoch 5/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 6/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 7.0174e-04 - val_mean_squared_error: 7.0174e-04
# Epoch 7/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 8/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 9/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 7.0101e-04 - val_mean_squared_error: 7.0101e-04
# Epoch 10/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 6.0234e-04 - val_mean_squared_error: 6.0234e-04
# Epoch 11/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 12/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 6.0542e-04 - val_mean_squared_error: 6.0542e-04
# Epoch 13/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 9.0380e-04 - val_mean_squared_error: 9.0380e-04
# Epoch 14/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 7.0349e-04 - val_mean_squared_error: 7.0349e-04
# Epoch 15/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 8.0259e-04 - val_mean_squared_error: 8.0259e-04
# Epoch 16/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 6.8867e-04 - val_mean_squared_error: 6.8867e-04
# Epoch 17/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 7.3885e-04 - val_mean_squared_error: 7.3885e-04
# Epoch 18/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 6.0180e-04 - val_mean_squared_error: 6.0180e-04
# Epoch 19/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 5.0298e-04 - val_mean_squared_error: 5.0298e-04
# Epoch 20/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 5.5237e-04 - val_mean_squared_error: 5.5237e-04
# Epoch 21/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 6.8882e-04 - val_mean_squared_error: 6.8882e-04
# Epoch 22/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 9.0830e-04 - val_mean_squared_error: 9.0830e-04
# Epoch 23/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 5.4547e-04 - val_mean_squared_error: 5.4547e-04
# Epoch 24/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 4.7510e-04 - val_mean_squared_error: 4.7510e-04
# Epoch 25/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 26/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 4.5768e-04 - val_mean_squared_error: 4.5768e-04
# Epoch 27/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 5.1796e-04 - val_mean_squared_error: 5.1796e-04
# Epoch 28/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 29/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 4.7580e-04 - val_mean_squared_error: 4.7580e-04
# Epoch 30/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 4.6556e-04 - val_mean_squared_error: 4.6556e-04
# Epoch 31/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 9.0373e-04 - val_mean_squared_error: 9.0373e-04
# Epoch 32/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 4.8455e-04 - val_mean_squared_error: 4.8455e-04
# Epoch 33/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 8.0215e-04 - val_mean_squared_error: 8.0215e-04
# Epoch 34/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 4.9694e-04 - val_mean_squared_error: 4.9694e-04
# Epoch 35/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 4.7524e-04 - val_mean_squared_error: 4.7524e-04
# Epoch 36/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 5.4694e-04 - val_mean_squared_error: 5.4694e-04
# Epoch 37/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 6.8746e-04 - val_mean_squared_error: 6.8746e-04
# Epoch 38/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 4.5629e-04 - val_mean_squared_error: 4.5629e-04
# Epoch 39/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 9.2815e-04 - val_mean_squared_error: 9.2815e-04
# Epoch 40/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 6.4148e-04 - val_mean_squared_error: 6.4148e-04
# Epoch 41/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 5.4911e-04 - val_mean_squared_error: 5.4911e-04
# Epoch 42/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 43/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 4.7123e-04 - val_mean_squared_error: 4.7123e-04
# Epoch 44/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 4.4032e-04 - val_mean_squared_error: 4.4032e-04
# Epoch 45/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 4.3703e-04 - val_mean_squared_error: 4.3703e-04
# Epoch 46/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 4.0655e-04 - val_mean_squared_error: 4.0655e-04
# Epoch 47/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 4.0716e-04 - val_mean_squared_error: 4.0716e-04
# Epoch 48/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 5.7145e-04 - val_mean_squared_error: 5.7145e-04
# Epoch 49/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 4.5514e-04 - val_mean_squared_error: 4.5514e-04
# Epoch 50/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 5.8226e-04 - val_mean_squared_error: 5.8226e-04
# Epoch 51/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 52/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 53/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 3.9450e-04 - val_mean_squared_error: 3.9450e-04
# Epoch 54/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 3.9268e-04 - val_mean_squared_error: 3.9268e-04
# Epoch 55/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 3.9708e-04 - val_mean_squared_error: 3.9708e-04
# Epoch 56/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 4.7370e-04 - val_mean_squared_error: 4.7370e-04
# Epoch 57/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 4.0456e-04 - val_mean_squared_error: 4.0456e-04
# Epoch 58/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 4.0591e-04 - val_mean_squared_error: 4.0591e-04
# Epoch 59/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 9.0157e-04 - val_mean_squared_error: 9.0157e-04
# Epoch 60/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 3.8886e-04 - val_mean_squared_error: 3.8886e-04
# Epoch 61/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 62/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 4.2159e-04 - val_mean_squared_error: 4.2159e-04
# Epoch 63/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 64/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 5.7249e-04 - val_mean_squared_error: 5.7249e-04
# Epoch 65/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 4.2108e-04 - val_mean_squared_error: 4.2108e-04
# Epoch 66/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 4.7016e-04 - val_mean_squared_error: 4.7016e-04
# Epoch 67/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 4.6928e-04 - val_mean_squared_error: 4.6928e-04
# Epoch 68/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 69/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 70/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 71/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 8.5288e-04 - val_mean_squared_error: 8.5288e-04
# Epoch 72/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 3.7908e-04 - val_mean_squared_error: 3.7908e-04
# Epoch 73/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 74/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 5.8198e-04 - val_mean_squared_error: 5.8198e-04
# Epoch 75/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 7.0499e-04 - val_mean_squared_error: 7.0499e-04
# Epoch 76/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.4770e-04 - val_mean_squared_error: 9.4770e-04
# Epoch 77/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 78/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 79/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 5.4485e-04 - val_mean_squared_error: 5.4485e-04
# Epoch 80/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 7.2159e-04 - val_mean_squared_error: 7.2159e-04
# Epoch 81/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 5.1299e-04 - val_mean_squared_error: 5.1299e-04
# Epoch 82/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 4.3493e-04 - val_mean_squared_error: 4.3493e-04
# Epoch 83/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 84/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 3.7585e-04 - val_mean_squared_error: 3.7585e-04
# Epoch 85/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 6.6636e-04 - val_mean_squared_error: 6.6636e-04
# Epoch 86/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 4.4302e-04 - val_mean_squared_error: 4.4302e-04
# Epoch 87/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 4.8375e-04 - val_mean_squared_error: 4.8375e-04
# Epoch 88/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.7270e-04 - val_mean_squared_error: 6.7270e-04
# Epoch 89/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 6.4087e-04 - val_mean_squared_error: 6.4087e-04
# Epoch 90/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 6.2986e-04 - val_mean_squared_error: 6.2986e-04
# Epoch 91/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 3.9804e-04 - val_mean_squared_error: 3.9804e-04
# Epoch 92/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 4.0759e-04 - val_mean_squared_error: 4.0759e-04
# Epoch 93/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 94/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 95/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 9.0308e-04 - val_mean_squared_error: 9.0308e-04
# Epoch 96/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 5.3042e-04 - val_mean_squared_error: 5.3042e-04
# Epoch 97/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 4.3118e-04 - val_mean_squared_error: 4.3118e-04
# Epoch 98/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 9.6391e-04 - val_mean_squared_error: 9.6391e-04
# Epoch 99/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 3.6915e-04 - val_mean_squared_error: 3.6915e-04
# Epoch 100/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 9.4370e-04 - val_mean_squared_error: 9.4370e-04
# Epoch 101/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.9095e-04 - val_mean_squared_error: 3.9095e-04
# Epoch 102/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.7244e-04 - val_mean_squared_error: 3.7244e-04
# Epoch 103/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 3.6583e-04 - val_mean_squared_error: 3.6583e-04
# Epoch 104/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 105/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 4.3520e-04 - val_mean_squared_error: 4.3520e-04
# Epoch 106/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 7.3112e-04 - val_mean_squared_error: 7.3112e-04
# Epoch 107/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 6.5770e-04 - val_mean_squared_error: 6.5770e-04
# Epoch 108/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.6510e-04 - val_mean_squared_error: 3.6510e-04
# Epoch 109/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 110/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 3.6567e-04 - val_mean_squared_error: 3.6567e-04
# Epoch 111/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.4072e-04 - val_mean_squared_error: 6.4072e-04
# Epoch 112/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 113/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 4.2583e-04 - val_mean_squared_error: 4.2583e-04
# Epoch 114/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.6451e-04 - val_mean_squared_error: 3.6451e-04
# Epoch 115/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 7.7084e-04 - val_mean_squared_error: 7.7084e-04
# Epoch 116/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 117/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 4.6181e-04 - val_mean_squared_error: 4.6181e-04
# Epoch 118/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 119/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 8.3484e-04 - val_mean_squared_error: 8.3484e-04
# Epoch 120/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 121/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 5.1304e-04 - val_mean_squared_error: 5.1304e-04
# Epoch 122/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 3.7171e-04 - val_mean_squared_error: 3.7171e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 4.4885e-04 - val_mean_squared_error: 4.4885e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 125/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 5.6819e-04 - val_mean_squared_error: 5.6819e-04
# Epoch 126/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.7721e-04 - val_mean_squared_error: 3.7721e-04
# Epoch 127/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 4.1205e-04 - val_mean_squared_error: 4.1205e-04
# Epoch 128/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 129/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 6.2334e-04 - val_mean_squared_error: 6.2334e-04
# Epoch 130/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 3.9942e-04 - val_mean_squared_error: 3.9942e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 4.5303e-04 - val_mean_squared_error: 4.5303e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 6.0850e-04 - val_mean_squared_error: 6.0850e-04
# Epoch 133/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 4.4845e-04 - val_mean_squared_error: 4.4845e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 3.9441e-04 - val_mean_squared_error: 3.9441e-04
# Epoch 135/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 7.3547e-04 - val_mean_squared_error: 7.3547e-04
# Epoch 136/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 5.9102e-04 - val_mean_squared_error: 5.9102e-04
# Epoch 137/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 138/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 139/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 4.1442e-04 - val_mean_squared_error: 4.1442e-04
# Epoch 139: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1046, 1) (296, 1) (146, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1046,) (296,) (146,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[19.318804]
#  [20.737741]
#  [21.020548]
#  [20.310862]
#  [20.491589]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[17.11 ]
#  [16.763]
#  [16.2  ]
#  [16.6  ]
#  [16.666]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE 
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))

#tinh mae va rmse chung
# Out:
# Train Mean Squared Error: 18.99244550901135
# Test Mean Squared Error: 13.576164150528617
# Val Mean Squared Error: 10.88528530886504
# Train Score: 18.99 RMSE
# Test Score: 13.58 RMSE
# Val Score: 10.89 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 13.77836729091825
# Test Mean Absolute Percentage Error: 3.0521112892248383
# Val Mean Absolute Percentage Error: 2.519867750680702
# Train Score: 13.78 MAPE
# Test Score: 3.05 MAPE
# Val Score: 2.52 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.47885193 0.45186109 0.45291074]
# day  1  have output =  0.44546267
# -----------------
# day  2  have input =  [0.45186109 0.45291074 0.44546267]
# day  2  have output =  0.44088942
# -----------------
# day  3  have input =  [0.45291074 0.44546267 0.44088942]
# day  3  have output =  0.4355073
# -----------------
# day  4  have input =  [0.44546267 0.44088942 0.4355073 ]
# day  4  have output =  0.430512
# -----------------
# day  5  have input =  [0.44088942 0.4355073  0.43051201]
# day  5  have output =  0.42550611
# -----------------
# day  6  have input =  [0.4355073  0.43051201 0.42550611]
# day  6  have output =  0.42061624
# -----------------
# day  7  have input =  [0.43051201 0.42550611 0.42061624]
# day  7  have output =  0.41579613
# -----------------
# day  8  have input =  [0.42550611 0.42061624 0.41579613]
# day  8  have output =  0.41105717
# -----------------
# day  9  have input =  [0.42061624 0.41579613 0.41105717]
# day  9  have output =  0.40639192
# -----------------
# day  10  have input =  [0.41579613 0.41105717 0.40639192]
# day  10  have output =  0.40179917
# -----------------
# day  11  have input =  [0.41105717 0.40639192 0.40179917]
# day  11  have output =  0.3972762
# -----------------
# day  12  have input =  [0.40639192 0.40179917 0.39727619]
# day  12  have output =  0.39282092
# -----------------
# day  13  have input =  [0.40179917 0.39727619 0.39282092]
# day  13  have output =  0.38843134
# -----------------
# day  14  have input =  [0.39727619 0.39282092 0.38843134]
# day  14  have output =  0.38410556
# -----------------
# day  15  have input =  [0.39282092 0.38843134 0.38410556]
# day  15  have output =  0.37984183
# -----------------
# day  16  have input =  [0.38843134 0.38410556 0.37984183]
# day  16  have output =  0.37563872
# -----------------
# day  17  have input =  [0.38410556 0.37984183 0.37563872]
# day  17  have output =  0.37149447
# -----------------
# day  18  have input =  [0.37984183 0.37563872 0.37149447]
# day  18  have output =  0.3674079
# -----------------
# day  19  have input =  [0.37563872 0.37149447 0.36740789]
# day  19  have output =  0.36337766
# -----------------
# day  20  have input =  [0.37149447 0.36740789 0.36337766]
# day  20  have output =  0.35940236
# -----------------
# day  21  have input =  [0.36740789 0.36337766 0.35940236]
# day  21  have output =  0.35548133
# -----------------
# day  22  have input =  [0.36337766 0.35940236 0.35548133]
# day  22  have output =  0.3516131
# -----------------
# day  23  have input =  [0.35940236 0.35548133 0.3516131 ]
# day  23  have output =  0.34779733
# -----------------
# day  24  have input =  [0.35548133 0.3516131  0.34779733]
# day  24  have output =  0.34403265
# -----------------
# day  25  have input =  [0.3516131  0.34779733 0.34403265]
# day  25  have output =  0.34031862
# -----------------
# day  26  have input =  [0.34779733 0.34403265 0.34031862]
# day  26  have output =  0.33665407
# -----------------
# day  27  have input =  [0.34403265 0.34031862 0.33665407]
# day  27  have output =  0.33303854
# -----------------
# day  28  have input =  [0.34031862 0.33665407 0.33303854]
# day  28  have output =  0.32947156
# -----------------
# day  29  have input =  [0.33665407 0.33303854 0.32947156]
# day  29  have output =  0.32595235
# -----------------
# day  30  have input =  [0.33303854 0.32947156 0.32595235]
# day  30  have output =  0.32248056

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.44546267, 0.44088942, 0.4355073, 0.430512, 0.42550611, 0.42061624, 0.41579613, 0.41105717, 0.40639192, 0.40179917, 0.3972762, 0.39282092, 0.38843134, 0.38410556, 0.37984183, 0.37563872, 0.37149447, 0.3674079, 0.36337766, 0.35940236, 0.35548133, 0.3516131, 0.34779733, 0.34403265, 0.34031862, 0.33665407, 0.33303854, 0.32947156, 0.32595235, 0.32248056]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[14.351]
#  [15.15 ]
#  [15.14 ]
#  [17.11 ]
#  [16.763]]
# [[511.9]
#  [506.9]
#  [474.1]
#  [472.6]
#  [448.1]]
# [[313.5]
#  [325.7]
#  [323.9]
#  [320.2]
#  [329.5]]
# [[306.33295]
#  [303.28308]
#  [299.69376]
#  [296.36246]
#  [293.02405]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
