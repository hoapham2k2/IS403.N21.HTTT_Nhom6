# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/ADAUSDT.xlsx')
df1=df.reset_index()['Close']

plt.plot(df1)

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (1050, 1) (300, 1) (150, 1)
# [[0.00985389]
#  [0.01189263]
#  [0.01359157]
#  [0.01325178]
#  [0.01223242]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (1046, 3) (1046,) (146, 3) (146,) (296, 3) (296,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00985389]
#   [0.01189263]
#   [0.01359157]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, SimpleRNN #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()
input_shape = (time_step, 1)
model.add(SimpleRNN(64, input_shape=input_shape, return_sequences=True))
model.add(SimpleRNN(32, input_shape=input_shape,return_sequences=True))
model.add(SimpleRNN(16))

model.add(Dense(5))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=25)
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (1046, 3, 1) (296, 3, 1) (146, 3, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=300,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/300
# 17/17 [==============================] - 3s 31ms/step - loss: 0.2805 - mean_squared_error: 0.2805 - val_loss: 0.0431 - val_mean_squared_error: 0.0431
# Epoch 2/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 3/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 4/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 5/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 9.2020e-04 - val_mean_squared_error: 9.2020e-04
# Epoch 6/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 9.6767e-04 - val_mean_squared_error: 9.6767e-04
# Epoch 7/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 7.8553e-04 - val_mean_squared_error: 7.8553e-04
# Epoch 8/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 9/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 10/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 11/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 12/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 9.8449e-04 - val_mean_squared_error: 9.8449e-04
# Epoch 13/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 14/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 8.1197e-04 - val_mean_squared_error: 8.1197e-04
# Epoch 15/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 16/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 17/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 18/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 8.6075e-04 - val_mean_squared_error: 8.6075e-04
# Epoch 19/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 20/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 8.8375e-04 - val_mean_squared_error: 8.8375e-04
# Epoch 21/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 8.3962e-04 - val_mean_squared_error: 8.3962e-04
# Epoch 22/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 8.5877e-04 - val_mean_squared_error: 8.5877e-04
# Epoch 23/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 24/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 6.9056e-04 - val_mean_squared_error: 6.9056e-04
# Epoch 25/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 7.8741e-04 - val_mean_squared_error: 7.8741e-04
# Epoch 26/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 8.4726e-04 - val_mean_squared_error: 8.4726e-04
# Epoch 27/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 28/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 6.7422e-04 - val_mean_squared_error: 6.7422e-04
# Epoch 29/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 9.4194e-04 - val_mean_squared_error: 9.4194e-04
# Epoch 30/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 6.6938e-04 - val_mean_squared_error: 6.6938e-04
# Epoch 31/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 7.1111e-04 - val_mean_squared_error: 7.1111e-04
# Epoch 32/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 8.9264e-04 - val_mean_squared_error: 8.9264e-04
# Epoch 33/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 6.3986e-04 - val_mean_squared_error: 6.3986e-04
# Epoch 34/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 5.3857e-04 - val_mean_squared_error: 5.3857e-04
# Epoch 35/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 5.3175e-04 - val_mean_squared_error: 5.3175e-04
# Epoch 36/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 6.8590e-04 - val_mean_squared_error: 6.8590e-04
# Epoch 37/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 7.4681e-04 - val_mean_squared_error: 7.4681e-04
# Epoch 38/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 8.9463e-04 - val_mean_squared_error: 8.9463e-04
# Epoch 39/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 4.6506e-04 - val_mean_squared_error: 4.6506e-04
# Epoch 40/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 7.9318e-04 - val_mean_squared_error: 7.9318e-04
# Epoch 41/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 5.2217e-04 - val_mean_squared_error: 5.2217e-04
# Epoch 42/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 5.5649e-04 - val_mean_squared_error: 5.5649e-04
# Epoch 43/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 44/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 4.8907e-04 - val_mean_squared_error: 4.8907e-04
# Epoch 45/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 46/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 4.7312e-04 - val_mean_squared_error: 4.7312e-04
# Epoch 47/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 5.4893e-04 - val_mean_squared_error: 5.4893e-04
# Epoch 48/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 5.9347e-04 - val_mean_squared_error: 5.9347e-04
# Epoch 49/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 4.1673e-04 - val_mean_squared_error: 4.1673e-04
# Epoch 50/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 5.1390e-04 - val_mean_squared_error: 5.1390e-04
# Epoch 51/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 4.4099e-04 - val_mean_squared_error: 4.4099e-04
# Epoch 52/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 3.5597e-04 - val_mean_squared_error: 3.5597e-04
# Epoch 53/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 5.5398e-04 - val_mean_squared_error: 5.5398e-04
# Epoch 54/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 3.7794e-04 - val_mean_squared_error: 3.7794e-04
# Epoch 55/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 4.3541e-04 - val_mean_squared_error: 4.3541e-04
# Epoch 56/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 4.3524e-04 - val_mean_squared_error: 4.3524e-04
# Epoch 57/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.1486e-04 - val_mean_squared_error: 6.1486e-04
# Epoch 58/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 3.5605e-04 - val_mean_squared_error: 3.5605e-04
# Epoch 59/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 6.6160e-04 - val_mean_squared_error: 6.6160e-04
# Epoch 60/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.3682e-04 - val_mean_squared_error: 3.3682e-04
# Epoch 61/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.3385e-04 - val_mean_squared_error: 3.3385e-04
# Epoch 62/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 4.4701e-04 - val_mean_squared_error: 4.4701e-04
# Epoch 63/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 3.8267e-04 - val_mean_squared_error: 3.8267e-04
# Epoch 64/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 3.9157e-04 - val_mean_squared_error: 3.9157e-04
# Epoch 65/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 3.7082e-04 - val_mean_squared_error: 3.7082e-04
# Epoch 66/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 3.4030e-04 - val_mean_squared_error: 3.4030e-04
# Epoch 67/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 3.1886e-04 - val_mean_squared_error: 3.1886e-04
# Epoch 68/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 3.4463e-04 - val_mean_squared_error: 3.4463e-04
# Epoch 69/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.3961e-04 - val_mean_squared_error: 3.3961e-04
# Epoch 70/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 3.3708e-04 - val_mean_squared_error: 3.3708e-04
# Epoch 71/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 7.1252e-04 - val_mean_squared_error: 7.1252e-04
# Epoch 72/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.3038e-04 - val_mean_squared_error: 3.3038e-04
# Epoch 73/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 3.2297e-04 - val_mean_squared_error: 3.2297e-04
# Epoch 74/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.4558e-04 - val_mean_squared_error: 3.4558e-04
# Epoch 75/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 3.5946e-04 - val_mean_squared_error: 3.5946e-04
# Epoch 76/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 3.0645e-04 - val_mean_squared_error: 3.0645e-04
# Epoch 77/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 3.0310e-04 - val_mean_squared_error: 3.0310e-04
# Epoch 78/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 3.1369e-04 - val_mean_squared_error: 3.1369e-04
# Epoch 79/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 3.2326e-04 - val_mean_squared_error: 3.2326e-04
# Epoch 80/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 4.2853e-04 - val_mean_squared_error: 4.2853e-04
# Epoch 81/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.9472e-04 - val_mean_squared_error: 2.9472e-04
# Epoch 82/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 3.3133e-04 - val_mean_squared_error: 3.3133e-04
# Epoch 83/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.2009e-04 - val_mean_squared_error: 3.2009e-04
# Epoch 84/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.9514e-04 - val_mean_squared_error: 2.9514e-04
# Epoch 85/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 4.0641e-04 - val_mean_squared_error: 4.0641e-04
# Epoch 86/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.8597e-04 - val_mean_squared_error: 2.8597e-04
# Epoch 87/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.9946e-04 - val_mean_squared_error: 2.9946e-04
# Epoch 88/300
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 3.0046e-04 - val_mean_squared_error: 3.0046e-04
# Epoch 89/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 3.4666e-04 - val_mean_squared_error: 3.4666e-04
# Epoch 90/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.8130e-04 - val_mean_squared_error: 2.8130e-04
# Epoch 91/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.8983e-04 - val_mean_squared_error: 2.8983e-04
# Epoch 92/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 2.8147e-04 - val_mean_squared_error: 2.8147e-04
# Epoch 93/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 3.3365e-04 - val_mean_squared_error: 3.3365e-04
# Epoch 94/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 2.8918e-04 - val_mean_squared_error: 2.8918e-04
# Epoch 95/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 4.0214e-04 - val_mean_squared_error: 4.0214e-04
# Epoch 96/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.7732e-04 - val_mean_squared_error: 2.7732e-04
# Epoch 97/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 2.8420e-04 - val_mean_squared_error: 2.8420e-04
# Epoch 98/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.7554e-04 - val_mean_squared_error: 2.7554e-04
# Epoch 99/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 3.6688e-04 - val_mean_squared_error: 3.6688e-04
# Epoch 100/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.8922e-04 - val_mean_squared_error: 2.8922e-04
# Epoch 101/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 4.1541e-04 - val_mean_squared_error: 4.1541e-04
# Epoch 102/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.6624e-04 - val_mean_squared_error: 2.6624e-04
# Epoch 103/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.7321e-04 - val_mean_squared_error: 2.7321e-04
# Epoch 104/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 3.9388e-04 - val_mean_squared_error: 3.9388e-04
# Epoch 105/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.7571e-04 - val_mean_squared_error: 2.7571e-04
# Epoch 106/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.1202e-04 - val_mean_squared_error: 3.1202e-04
# Epoch 107/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 4.1231e-04 - val_mean_squared_error: 4.1231e-04
# Epoch 108/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 2.6262e-04 - val_mean_squared_error: 2.6262e-04
# Epoch 109/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.5772e-04 - val_mean_squared_error: 2.5772e-04
# Epoch 110/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.4264e-04 - val_mean_squared_error: 3.4264e-04
# Epoch 111/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.9566e-04 - val_mean_squared_error: 2.9566e-04
# Epoch 112/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.0255e-04 - val_mean_squared_error: 3.0255e-04
# Epoch 113/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.6871e-04 - val_mean_squared_error: 3.6871e-04
# Epoch 114/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 2.6966e-04 - val_mean_squared_error: 2.6966e-04
# Epoch 115/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.9129e-04 - val_mean_squared_error: 2.9129e-04
# Epoch 116/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 3.3554e-04 - val_mean_squared_error: 3.3554e-04
# Epoch 117/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 4.1682e-04 - val_mean_squared_error: 4.1682e-04
# Epoch 118/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 2.6246e-04 - val_mean_squared_error: 2.6246e-04
# Epoch 119/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.5336e-04 - val_mean_squared_error: 2.5336e-04
# Epoch 120/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.5528e-04 - val_mean_squared_error: 2.5528e-04
# Epoch 121/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 4.6601e-04 - val_mean_squared_error: 4.6601e-04
# Epoch 122/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 3.1460e-04 - val_mean_squared_error: 3.1460e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 3.6958e-04 - val_mean_squared_error: 3.6958e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 2.6197e-04 - val_mean_squared_error: 2.6197e-04
# Epoch 125/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 2.7038e-04 - val_mean_squared_error: 2.7038e-04
# Epoch 126/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.5622e-04 - val_mean_squared_error: 2.5622e-04
# Epoch 127/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.2100e-04 - val_mean_squared_error: 3.2100e-04
# Epoch 128/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.7357e-04 - val_mean_squared_error: 2.7357e-04
# Epoch 129/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 3.2997e-04 - val_mean_squared_error: 3.2997e-04
# Epoch 130/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 4.5483e-04 - val_mean_squared_error: 4.5483e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 2.6451e-04 - val_mean_squared_error: 2.6451e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.4404e-04 - val_mean_squared_error: 2.4404e-04
# Epoch 133/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 2.5973e-04 - val_mean_squared_error: 2.5973e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.5413e-04 - val_mean_squared_error: 2.5413e-04
# Epoch 135/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 4.9300e-04 - val_mean_squared_error: 4.9300e-04
# Epoch 136/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.3569e-04 - val_mean_squared_error: 2.3569e-04
# Epoch 137/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.9732e-04 - val_mean_squared_error: 2.9732e-04
# Epoch 138/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.4119e-04 - val_mean_squared_error: 2.4119e-04
# Epoch 139/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.7655e-04 - val_mean_squared_error: 2.7655e-04
# Epoch 140/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 2.3066e-04 - val_mean_squared_error: 2.3066e-04
# Epoch 141/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.2928e-04 - val_mean_squared_error: 2.2928e-04
# Epoch 142/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.5692e-04 - val_mean_squared_error: 2.5692e-04
# Epoch 143/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.2950e-04 - val_mean_squared_error: 2.2950e-04
# Epoch 144/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.8633e-04 - val_mean_squared_error: 2.8633e-04
# Epoch 145/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 3.3266e-04 - val_mean_squared_error: 3.3266e-04
# Epoch 146/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 3.7457e-04 - val_mean_squared_error: 3.7457e-04
# Epoch 147/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.5976e-04 - val_mean_squared_error: 2.5976e-04
# Epoch 148/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 3.1448e-04 - val_mean_squared_error: 3.1448e-04
# Epoch 149/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 3.2630e-04 - val_mean_squared_error: 3.2630e-04
# Epoch 150/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 4.3474e-04 - val_mean_squared_error: 4.3474e-04
# Epoch 151/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.6217e-04 - val_mean_squared_error: 2.6217e-04
# Epoch 152/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 8.0124e-04 - val_mean_squared_error: 8.0124e-04
# Epoch 153/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 3.3060e-04 - val_mean_squared_error: 3.3060e-04
# Epoch 154/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 2.3460e-04 - val_mean_squared_error: 2.3460e-04
# Epoch 155/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 3.5377e-04 - val_mean_squared_error: 3.5377e-04
# Epoch 156/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 3.7247e-04 - val_mean_squared_error: 3.7247e-04
# Epoch 157/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 2.4573e-04 - val_mean_squared_error: 2.4573e-04
# Epoch 158/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.2382e-04 - val_mean_squared_error: 2.2382e-04
# Epoch 159/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.3681e-04 - val_mean_squared_error: 2.3681e-04
# Epoch 160/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.2151e-04 - val_mean_squared_error: 2.2151e-04
# Epoch 161/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 2.7425e-04 - val_mean_squared_error: 2.7425e-04
# Epoch 162/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.2709e-04 - val_mean_squared_error: 4.2709e-04
# Epoch 163/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 4.3281e-04 - val_mean_squared_error: 4.3281e-04
# Epoch 164/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.3991e-04 - val_mean_squared_error: 2.3991e-04
# Epoch 165/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.5019e-04 - val_mean_squared_error: 2.5019e-04
# Epoch 166/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 2.2081e-04 - val_mean_squared_error: 2.2081e-04
# Epoch 167/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 4.7321e-04 - val_mean_squared_error: 4.7321e-04
# Epoch 168/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 2.9406e-04 - val_mean_squared_error: 2.9406e-04
# Epoch 169/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.7319e-04 - val_mean_squared_error: 2.7319e-04
# Epoch 170/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.1927e-04 - val_mean_squared_error: 2.1927e-04
# Epoch 171/300
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.1911e-04 - val_mean_squared_error: 2.1911e-04
# Epoch 172/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 3.9876e-04 - val_mean_squared_error: 3.9876e-04
# Epoch 173/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 3.2419e-04 - val_mean_squared_error: 3.2419e-04
# Epoch 174/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.2067e-04 - val_mean_squared_error: 2.2067e-04
# Epoch 175/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.6172e-04 - val_mean_squared_error: 2.6172e-04
# Epoch 176/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 6.5768e-04 - val_mean_squared_error: 6.5768e-04
# Epoch 177/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.1584e-04 - val_mean_squared_error: 2.1584e-04
# Epoch 178/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.1599e-04 - val_mean_squared_error: 2.1599e-04
# Epoch 179/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.1867e-04 - val_mean_squared_error: 2.1867e-04
# Epoch 180/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.1801e-04 - val_mean_squared_error: 2.1801e-04
# Epoch 181/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.2763e-04 - val_mean_squared_error: 2.2763e-04
# Epoch 182/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 2.2212e-04 - val_mean_squared_error: 2.2212e-04
# Epoch 183/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.3906e-04 - val_mean_squared_error: 2.3906e-04
# Epoch 184/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.4115e-04 - val_mean_squared_error: 2.4115e-04
# Epoch 185/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.2073e-04 - val_mean_squared_error: 2.2073e-04
# Epoch 186/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.4753e-04 - val_mean_squared_error: 2.4753e-04
# Epoch 187/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 2.1921e-04 - val_mean_squared_error: 2.1921e-04
# Epoch 188/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 4.3808e-04 - val_mean_squared_error: 4.3808e-04
# Epoch 189/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 3.6223e-04 - val_mean_squared_error: 3.6223e-04
# Epoch 190/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.4076e-04 - val_mean_squared_error: 2.4076e-04
# Epoch 191/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.0916e-04 - val_mean_squared_error: 3.0916e-04
# Epoch 192/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.3007e-04 - val_mean_squared_error: 2.3007e-04
# Epoch 193/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.2624e-04 - val_mean_squared_error: 3.2624e-04
# Epoch 194/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 9.4003e-04 - val_mean_squared_error: 9.4003e-04
# Epoch 195/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.4794e-04 - val_mean_squared_error: 2.4794e-04
# Epoch 196/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.0927e-04 - val_mean_squared_error: 2.0927e-04
# Epoch 197/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.0669e-04 - val_mean_squared_error: 2.0669e-04
# Epoch 198/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 2.0827e-04 - val_mean_squared_error: 2.0827e-04
# Epoch 199/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 4.9179e-04 - val_mean_squared_error: 4.9179e-04
# Epoch 200/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.0606e-04 - val_mean_squared_error: 2.0606e-04
# Epoch 201/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.2885e-04 - val_mean_squared_error: 2.2885e-04
# Epoch 202/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 2.0404e-04 - val_mean_squared_error: 2.0404e-04
# Epoch 203/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.7301e-04 - val_mean_squared_error: 2.7301e-04
# Epoch 204/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.1549e-04 - val_mean_squared_error: 2.1549e-04
# Epoch 205/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.4839e-04 - val_mean_squared_error: 2.4839e-04
# Epoch 206/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.0872e-04 - val_mean_squared_error: 2.0872e-04
# Epoch 207/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.1326e-04 - val_mean_squared_error: 2.1326e-04
# Epoch 208/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 2.3527e-04 - val_mean_squared_error: 2.3527e-04
# Epoch 209/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 2.0340e-04 - val_mean_squared_error: 2.0340e-04
# Epoch 210/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.0792e-04 - val_mean_squared_error: 2.0792e-04
# Epoch 211/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 3.3673e-04 - val_mean_squared_error: 3.3673e-04
# Epoch 212/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.6522e-04 - val_mean_squared_error: 2.6522e-04
# Epoch 213/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.4044e-04 - val_mean_squared_error: 2.4044e-04
# Epoch 214/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 2.0652e-04 - val_mean_squared_error: 2.0652e-04
# Epoch 215/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.0251e-04 - val_mean_squared_error: 2.0251e-04
# Epoch 216/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.3391e-04 - val_mean_squared_error: 2.3391e-04
# Epoch 217/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.0674e-04 - val_mean_squared_error: 2.0674e-04
# Epoch 218/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 2.1074e-04 - val_mean_squared_error: 2.1074e-04
# Epoch 219/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.1865e-04 - val_mean_squared_error: 2.1865e-04
# Epoch 220/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.0768e-04 - val_mean_squared_error: 2.0768e-04
# Epoch 221/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 3.4561e-04 - val_mean_squared_error: 3.4561e-04
# Epoch 222/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.2966e-04 - val_mean_squared_error: 2.2966e-04
# Epoch 223/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.0381e-04 - val_mean_squared_error: 2.0381e-04
# Epoch 224/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 1.9856e-04 - val_mean_squared_error: 1.9856e-04
# Epoch 225/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.2882e-04 - val_mean_squared_error: 2.2882e-04
# Epoch 226/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.5167e-04 - val_mean_squared_error: 2.5167e-04
# Epoch 227/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.3414e-04 - val_mean_squared_error: 2.3414e-04
# Epoch 228/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 1.9786e-04 - val_mean_squared_error: 1.9786e-04
# Epoch 229/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 6.1916e-04 - val_mean_squared_error: 6.1916e-04
# Epoch 230/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 2.8411e-04 - val_mean_squared_error: 2.8411e-04
# Epoch 231/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 3.2820e-04 - val_mean_squared_error: 3.2820e-04
# Epoch 232/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 3.8990e-04 - val_mean_squared_error: 3.8990e-04
# Epoch 233/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 4.1308e-04 - val_mean_squared_error: 4.1308e-04
# Epoch 234/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 8.2769e-04 - val_mean_squared_error: 8.2769e-04
# Epoch 235/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.8984e-04 - val_mean_squared_error: 2.8984e-04
# Epoch 236/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.9495e-04 - val_mean_squared_error: 2.9495e-04
# Epoch 237/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 2.7143e-04 - val_mean_squared_error: 2.7143e-04
# Epoch 238/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 2.0412e-04 - val_mean_squared_error: 2.0412e-04
# Epoch 239/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 3.5741e-04 - val_mean_squared_error: 3.5741e-04
# Epoch 240/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.3161e-04 - val_mean_squared_error: 2.3161e-04
# Epoch 241/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 3.6568e-04 - val_mean_squared_error: 3.6568e-04
# Epoch 242/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.2851e-04 - val_mean_squared_error: 2.2851e-04
# Epoch 243/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.2840e-04 - val_mean_squared_error: 2.2840e-04
# Epoch 244/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 1.9695e-04 - val_mean_squared_error: 1.9695e-04
# Epoch 245/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 2.0081e-04 - val_mean_squared_error: 2.0081e-04
# Epoch 246/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 1.9960e-04 - val_mean_squared_error: 1.9960e-04
# Epoch 247/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 2.0114e-04 - val_mean_squared_error: 2.0114e-04
# Epoch 248/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.6260e-04 - val_mean_squared_error: 2.6260e-04
# Epoch 249/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 3.0855e-04 - val_mean_squared_error: 3.0855e-04
# Epoch 250/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 2.6476e-04 - val_mean_squared_error: 2.6476e-04
# Epoch 251/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 3.7272e-04 - val_mean_squared_error: 3.7272e-04
# Epoch 252/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 1.9821e-04 - val_mean_squared_error: 1.9821e-04
# Epoch 253/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 2.9627e-04 - val_mean_squared_error: 2.9627e-04
# Epoch 254/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.0346e-04 - val_mean_squared_error: 2.0346e-04
# Epoch 255/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 1.9544e-04 - val_mean_squared_error: 1.9544e-04
# Epoch 256/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 1.9494e-04 - val_mean_squared_error: 1.9494e-04
# Epoch 257/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 2.4330e-04 - val_mean_squared_error: 2.4330e-04
# Epoch 258/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 1.9402e-04 - val_mean_squared_error: 1.9402e-04
# Epoch 259/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 6.1463e-04 - val_mean_squared_error: 6.1463e-04
# Epoch 260/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 2.9072e-04 - val_mean_squared_error: 2.9072e-04
# Epoch 261/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.3891e-04 - val_mean_squared_error: 2.3891e-04
# Epoch 262/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.5950e-04 - val_mean_squared_error: 2.5950e-04
# Epoch 263/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 1.9751e-04 - val_mean_squared_error: 1.9751e-04
# Epoch 264/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 2.2797e-04 - val_mean_squared_error: 2.2797e-04
# Epoch 265/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 8.1369e-04 - val_mean_squared_error: 8.1369e-04
# Epoch 266/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 2.7902e-04 - val_mean_squared_error: 2.7902e-04
# Epoch 267/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.0670e-04 - val_mean_squared_error: 2.0670e-04
# Epoch 268/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.0216e-04 - val_mean_squared_error: 2.0216e-04
# Epoch 269/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 2.3422e-04 - val_mean_squared_error: 2.3422e-04
# Epoch 270/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 1.9926e-04 - val_mean_squared_error: 1.9926e-04
# Epoch 271/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.5094e-04 - val_mean_squared_error: 2.5094e-04
# Epoch 272/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.1307e-04 - val_mean_squared_error: 2.1307e-04
# Epoch 273/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 1.9335e-04 - val_mean_squared_error: 1.9335e-04
# Epoch 274/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 6.2985e-04 - val_mean_squared_error: 6.2985e-04
# Epoch 275/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.3888e-04 - val_mean_squared_error: 2.3888e-04
# Epoch 276/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.2741e-04 - val_mean_squared_error: 2.2741e-04
# Epoch 277/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.1962e-04 - val_mean_squared_error: 2.1962e-04
# Epoch 278/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 4.2623e-04 - val_mean_squared_error: 4.2623e-04
# Epoch 279/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 5.0540e-04 - val_mean_squared_error: 5.0540e-04
# Epoch 280/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.0489e-04 - val_mean_squared_error: 2.0489e-04
# Epoch 281/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 2.0099e-04 - val_mean_squared_error: 2.0099e-04
# Epoch 282/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 2.4117e-04 - val_mean_squared_error: 2.4117e-04
# Epoch 283/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.2289e-04 - val_mean_squared_error: 2.2289e-04
# Epoch 284/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 2.0636e-04 - val_mean_squared_error: 2.0636e-04
# Epoch 285/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 1.9439e-04 - val_mean_squared_error: 1.9439e-04
# Epoch 286/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.0480e-04 - val_mean_squared_error: 2.0480e-04
# Epoch 287/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 1.9512e-04 - val_mean_squared_error: 1.9512e-04
# Epoch 288/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 2.1036e-04 - val_mean_squared_error: 2.1036e-04
# Epoch 289/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 3.0815e-04 - val_mean_squared_error: 3.0815e-04
# Epoch 290/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 2.3858e-04 - val_mean_squared_error: 2.3858e-04
# Epoch 291/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 3.4066e-04 - val_mean_squared_error: 3.4066e-04
# Epoch 292/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 2.4705e-04 - val_mean_squared_error: 2.4705e-04
# Epoch 293/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 1.9922e-04 - val_mean_squared_error: 1.9922e-04
# Epoch 294/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.3395e-04 - val_mean_squared_error: 2.3395e-04
# Epoch 295/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 2.0829e-04 - val_mean_squared_error: 2.0829e-04
# Epoch 296/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 2.0875e-04 - val_mean_squared_error: 2.0875e-04
# Epoch 297/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 3.0137e-04 - val_mean_squared_error: 3.0137e-04
# Epoch 298/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 3.1108e-04 - val_mean_squared_error: 3.1108e-04
# Epoch 298: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 33/33 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1046, 1) (296, 1) (146, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1046,) (296,) (146,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[0.07576402]
#  [0.07545479]
#  [0.07275188]
#  [0.0748328 ]
#  [0.07938146]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.062]
#  [0.059]
#  [0.062]
#  [0.067]
#  [0.066]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE 
import math
from sklearn.metrics import mean_squared_error
print('Train Mean Squared Error:', math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0])))
print('Test Mean Squared Error:', math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0])))
print('Val Mean Squared Error:', math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0])))
print('Train Score: %.2f RMSE' % (math.sqrt(mean_squared_error(y_train[:,0], train_predict[:,0]))))
print('Test Score: %.2f RMSE' % (math.sqrt(mean_squared_error(ytest[:,0], y_pred[:,0]))))
print('Val Score: %.2f RMSE' % (math.sqrt(mean_squared_error(yval[:,0], y_pred_val[:,0]))))

#tinh mae va rmse chung
# Out:
# Train Mean Squared Error: 0.09268905568755371
# Test Mean Squared Error: 0.051906773767248345
# Val Mean Squared Error: 0.014909408026812931
# Train Score: 0.09 RMSE
# Test Score: 0.05 RMSE
# Val Score: 0.01 RMSE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 16.920104298957984
# Test Mean Absolute Percentage Error: 4.919375807119374
# Val Mean Absolute Percentage Error: 3.0856127084805065
# Train Score: 16.92 MAPE
# Test Score: 4.92 MAPE
# Val Score: 3.09 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.11314985 0.10941216 0.11043153]
# day  1  have output =  0.10758729
# -----------------
# day  2  have input =  [0.10941216 0.11043153 0.10758729]
# day  2  have output =  0.1054513
# -----------------
# day  3  have input =  [0.11043153 0.10758729 0.1054513 ]
# day  3  have output =  0.103323385
# -----------------
# day  4  have input =  [0.10758729 0.1054513  0.10332339]
# day  4  have output =  0.10135725
# -----------------
# day  5  have input =  [0.1054513  0.10332339 0.10135725]
# day  5  have output =  0.09951302
# -----------------
# day  6  have input =  [0.10332339 0.10135725 0.09951302]
# day  6  have output =  0.09778926
# -----------------
# day  7  have input =  [0.10135725 0.09951302 0.09778926]
# day  7  have output =  0.09617697
# -----------------
# day  8  have input =  [0.09951302 0.09778926 0.09617697]
# day  8  have output =  0.09466961
# -----------------
# day  9  have input =  [0.09778926 0.09617697 0.09466961]
# day  9  have output =  0.09326036
# -----------------
# day  10  have input =  [0.09617697 0.09466961 0.09326036]
# day  10  have output =  0.091942966
# -----------------
# day  11  have input =  [0.09466961 0.09326036 0.09194297]
# day  11  have output =  0.09071157
# -----------------
# day  12  have input =  [0.09326036 0.09194297 0.09071157]
# day  12  have output =  0.08956066
# -----------------
# day  13  have input =  [0.09194297 0.09071157 0.08956066]
# day  13  have output =  0.08848511
# -----------------
# day  14  have input =  [0.09071157 0.08956066 0.08848511]
# day  14  have output =  0.08748002
# -----------------
# day  15  have input =  [0.08956066 0.08848511 0.08748002]
# day  15  have output =  0.086540826
# -----------------
# day  16  have input =  [0.08848511 0.08748002 0.08654083]
# day  16  have output =  0.08566336
# -----------------
# day  17  have input =  [0.08748002 0.08654083 0.08566336]
# day  17  have output =  0.084843576
# -----------------
# day  18  have input =  [0.08654083 0.08566336 0.08484358]
# day  18  have output =  0.08407773
# -----------------
# day  19  have input =  [0.08566336 0.08484358 0.08407773]
# day  19  have output =  0.08336232
# -----------------
# day  20  have input =  [0.08484358 0.08407773 0.08336232]
# day  20  have output =  0.082694046
# -----------------
# day  21  have input =  [0.08407773 0.08336232 0.08269405]
# day  21  have output =  0.08206983
# -----------------
# day  22  have input =  [0.08336232 0.08269405 0.08206983]
# day  22  have output =  0.08148684
# -----------------
# day  23  have input =  [0.08269405 0.08206983 0.08148684]
# day  23  have output =  0.08094233
# -----------------
# day  24  have input =  [0.08206983 0.08148684 0.08094233]
# day  24  have output =  0.080433816
# -----------------
# day  25  have input =  [0.08148684 0.08094233 0.08043382]
# day  25  have output =  0.07995892
# -----------------
# day  26  have input =  [0.08094233 0.08043382 0.07995892]
# day  26  have output =  0.07951542
# -----------------
# day  27  have input =  [0.08043382 0.07995892 0.07951542]
# day  27  have output =  0.07910134
# -----------------
# day  28  have input =  [0.07995892 0.07951542 0.07910134]
# day  28  have output =  0.07871465
# -----------------
# day  29  have input =  [0.07951542 0.07910134 0.07871465]
# day  29  have output =  0.07835359
# -----------------
# day  30  have input =  [0.07910134 0.07871465 0.07835359]
# day  30  have output =  0.07801643

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.10758729, 0.1054513, 0.103323385, 0.10135725, 0.09951302, 0.09778926, 0.09617697, 0.09466961, 0.09326036, 0.091942966, 0.09071157, 0.08956066, 0.08848511, 0.08748002, 0.086540826, 0.08566336, 0.084843576, 0.08407773, 0.08336232, 0.082694046, 0.08206983, 0.08148684, 0.08094233, 0.080433816, 0.07995892, 0.07951542, 0.07910134, 0.07871465, 0.07835359, 0.07801643]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.052]
#  [0.058]
#  [0.063]
#  [0.062]
#  [0.059]]
# [[1.319]
#  [1.309]
#  [1.23 ]
#  [1.28 ]
#  [1.21 ]]
# [[0.406]
#  [0.406]
#  [0.401]
#  [0.386]
#  [0.39 ]]
# [[0.33962938]
#  [0.33334318]
#  [0.32708073]
#  [0.3212944 ]
#  [0.3158668 ]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
