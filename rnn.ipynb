# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('../../Dataset/ETHUSDT.xlsx')
df1=df.reset_index()['Close']

plt.plot(df1)

# %%
#đảo ngược dữ liệu
df1=df1.loc[::-1].reset_index(drop=True)
df=df.loc[::-1].reset_index(drop=True)

# %%
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.6 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
#in shape của từng tập dư liệu
print(train_data.shape, test_data.shape, val_data.shape)

#in head
print(df1[:5])
# Out:
# (900, 1) (300, 1) (300, 1)
# [[0.00575087]
#  [0.00599129]
#  [0.00626787]
#  [0.00601469]
#  [0.00556577]]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 10
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
#in shape của từng tập dư liệu
print(X_train.shape, y_train.shape, X_val.shape, yval.shape, X_test.shape, ytest.shape)
# Out:
# (889, 10) (889,) (289, 10) (289,) (289, 10) (289,)

# %%
# # 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (889, 10, 1) (289, 10, 1) (289, 10, 1)

# %%
#in dữ liệu
print(X_train[:1])
# Out:
# [[[0.00575087]
#   [0.00599129]
#   [0.00626787]
#   [0.00601469]
#   [0.00556577]
#   [0.00560832]
#   [0.00672956]
#   [0.00639127]
#   [0.00753804]
#   [0.00736996]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, SimpleRNN #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import mean_squared_error




# Tạo model
model = Sequential()
input_shape = (time_step, 1)
model.add(SimpleRNN(64, input_shape=input_shape, return_sequences=True))
model.add(SimpleRNN(32, input_shape=input_shape,return_sequences=True))
model.add(SimpleRNN(16))

model.add(Dense(5))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics 
model.compile (loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['mean_squared_error'])
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True) 
#mode = min tìm min của val_loss verbose = 1 in ra thông báo patience = 25 sau 25 epoch mà val_loss không giảm thì dừng lại
#baseline = 0.0001 nếu val_loss nhỏ hơn 0.0001 thì dừng lại
#restore_best_weights = True lấy lại trọng số tốt nhất của model 
#verbose = 1 in ra thông báo khi dung early_stop, 1 là in ra, 0 là không in ra

# %%
#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape, X_val.shape)
# Out:
# (889, 10, 1) (289, 10, 1) (289, 10, 1)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=2000,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/2000
# 14/14 [==============================] - 3s 38ms/step - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.1386 - val_mean_squared_error: 0.1386
# Epoch 2/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.1250 - val_mean_squared_error: 0.1250
# Epoch 3/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0880 - val_mean_squared_error: 0.0880
# Epoch 4/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0456 - val_mean_squared_error: 0.0456
# Epoch 5/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0613 - val_mean_squared_error: 0.0613
# Epoch 6/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Epoch 7/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0566 - val_mean_squared_error: 0.0566
# Epoch 8/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0505 - val_mean_squared_error: 0.0505
# Epoch 9/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 10/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 11/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 12/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 13/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 14/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 15/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 16/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 17/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 18/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 19/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 20/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 21/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 22/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 23/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 24/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 25/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 26/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 27/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 28/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 29/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 30/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 31/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 32/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 33/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 34/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 35/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 36/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 37/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 38/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 39/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 40/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 41/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 42/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 43/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 44/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 45/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 46/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 47/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 48/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 49/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 50/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 51/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 52/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 53/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 54/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 55/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 56/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 57/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 58/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 59/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 60/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 61/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 62/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 63/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 64/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 65/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 66/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 67/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 68/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 69/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 70/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 71/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 72/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 73/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 74/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 75/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 76/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 77/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 78/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 79/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 80/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 81/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 82/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 83/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 84/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 85/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 86/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 87/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 88/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 89/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 90/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 91/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 92/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 93/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 94/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 95/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 96/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 97/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 98/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 99/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 100/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 101/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 102/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 103/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 104/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 105/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 106/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 107/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 108/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 109/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 110/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 111/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 112/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 113/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 114/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 115/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 116/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 117/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 118/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 119/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 120/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 121/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 122/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 123/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 124/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 125/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 126/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 127/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 128/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 129/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 130/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 131/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 132/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 133/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 134/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 135/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 136/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 137/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 138/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 139/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 140/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 141/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 142/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 143/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 144/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 145/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 146/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 147/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 148/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 149/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 150/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 151/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 152/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 153/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 154/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 155/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 156/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 157/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 158/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 159/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 160/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 161/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 162/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 163/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 164/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 165/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 166/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 167/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 168/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 169/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 170/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 171/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 172/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 173/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 174/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 175/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 176/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 177/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 178/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 179/2000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 180/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 181/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 182/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 183/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 184/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 185/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 186/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 187/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 188/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 189/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 190/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 191/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 192/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 193/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 194/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 195/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 196/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 197/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 198/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 199/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 200/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 201/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 202/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 203/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 204/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 205/2000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 206/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 207/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 208/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 209/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 210/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 211/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 212/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 213/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 214/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 215/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 216/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 217/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 218/2000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 219/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 220/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 221/2000
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025Restoring model weights from the end of the best epoch: 171.
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 221: early stopping

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

#in shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 28/28 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# (889, 1) (289, 1) (289, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (889,) (289,) (289,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

#in head
print(train_predict[:5])
# Out:
# [[ 98.59945 ]
#  [ 91.285675]
#  [100.83359 ]
#  [116.367455]
#  [125.717995]]

# %%
#Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[141.38]
#  [141.24]
#  [163.31]
#  [159.96]
#  [157.36]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng MAE va RMSE 
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#Đánh giá độ chính xác thuật toán bằng RMSE
trainScore = math.sqrt(mean_squared_error(y_train,train_predict))
print('Train Score: %.3f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(ytest,y_pred))
print('Test Score: %.3f RMSE' % (testScore))
valScore = math.sqrt(mean_squared_error(yval,y_pred_val))
print('Val Score: %.3f RMSE' % (valScore))

#Đánh giá độ chính xác thuật toán bằng MAE
trainScore = mean_absolute_error(y_train,train_predict)
print('Train Score: %.3f MAE' % (trainScore))
testScore = mean_absolute_error(ytest,y_pred)
print('Test Score: %.3f MAE' % (testScore))
valScore = mean_absolute_error(yval,y_pred_val)
print('Val Score: %.3f MAE' % (valScore))
# Out:
# Train Score: 93.167 RMSE
# Test Score: 175.977 RMSE
# Val Score: 70.789 RMSE
# Train Score: 68.082 MAE
# Test Score: 133.618 MAE
# Val Score: 51.292 MAE

# %%
# Danh gia model bang mat do MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 17.541380916826576
# Test Mean Absolute Percentage Error: 3.9431667093071927
# Val Mean Absolute Percentage Error: 3.6432296652687928
# Train Score: 17.54 MAPE
# Test Score: 3.94 MAPE
# Val Score: 3.64 MAPE

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])
    
    
    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (10, 1)
# -----------------
# day  1  have input =  [0.35591554 0.3457244  0.36028773 0.34605418 0.36295998 0.34929662
#  0.34766051 0.35446878 0.34198836 0.34230537]
# day  1  have output =  0.3415301
# -----------------
# day  2  have input =  [0.3457244  0.36028773 0.34605418 0.36295998 0.34929662 0.34766051
#  0.35446878 0.34198836 0.34230537 0.34153011]
# day  2  have output =  0.34690478
# -----------------
# day  3  have input =  [0.36028773 0.34605418 0.36295998 0.34929662 0.34766051 0.35446878
#  0.34198836 0.34230537 0.34153011 0.34690478]
# day  3  have output =  0.34141868
# -----------------
# day  4  have input =  [0.34605418 0.36295998 0.34929662 0.34766051 0.35446878 0.34198836
#  0.34230537 0.34153011 0.34690478 0.34141868]
# day  4  have output =  0.34922677
# -----------------
# day  5  have input =  [0.36295998 0.34929662 0.34766051 0.35446878 0.34198836 0.34230537
#  0.34153011 0.34690478 0.34141868 0.34922677]
# day  5  have output =  0.34943002
# -----------------
# day  6  have input =  [0.34929662 0.34766051 0.35446878 0.34198836 0.34230537 0.34153011
#  0.34690478 0.34141868 0.34922677 0.34943002]
# day  6  have output =  0.34849244
# -----------------
# day  7  have input =  [0.34766051 0.35446878 0.34198836 0.34230537 0.34153011 0.34690478
#  0.34141868 0.34922677 0.34943002 0.34849244]
# day  7  have output =  0.35354757
# -----------------
# day  8  have input =  [0.35446878 0.34198836 0.34230537 0.34153011 0.34690478 0.34141868
#  0.34922677 0.34943002 0.34849244 0.35354757]
# day  8  have output =  0.35530362
# -----------------
# day  9  have input =  [0.34198836 0.34230537 0.34153011 0.34690478 0.34141868 0.34922677
#  0.34943002 0.34849244 0.35354757 0.35530362]
# day  9  have output =  0.35752118
# -----------------
# day  10  have input =  [0.34230537 0.34153011 0.34690478 0.34141868 0.34922677 0.34943002
#  0.34849244 0.35354757 0.35530362 0.35752118]
# day  10  have output =  0.3582476
# -----------------
# day  11  have input =  [0.34153011 0.34690478 0.34141868 0.34922677 0.34943002 0.34849244
#  0.35354757 0.35530362 0.35752118 0.35824761]
# day  11  have output =  0.36290187
# -----------------
# day  12  have input =  [0.34690478 0.34141868 0.34922677 0.34943002 0.34849244 0.35354757
#  0.35530362 0.35752118 0.35824761 0.36290187]
# day  12  have output =  0.36217657
# -----------------
# day  13  have input =  [0.34141868 0.34922677 0.34943002 0.34849244 0.35354757 0.35530362
#  0.35752118 0.35824761 0.36290187 0.36217657]
# day  13  have output =  0.36495313
# -----------------
# day  14  have input =  [0.34922677 0.34943002 0.34849244 0.35354757 0.35530362 0.35752118
#  0.35824761 0.36290187 0.36217657 0.36495313]
# day  14  have output =  0.36772823
# -----------------
# day  15  have input =  [0.34943002 0.34849244 0.35354757 0.35530362 0.35752118 0.35824761
#  0.36290187 0.36217657 0.36495313 0.36772823]
# day  15  have output =  0.36897704
# -----------------
# day  16  have input =  [0.34849244 0.35354757 0.35530362 0.35752118 0.35824761 0.36290187
#  0.36217657 0.36495313 0.36772823 0.36897704]
# day  16  have output =  0.3709054
# -----------------
# day  17  have input =  [0.35354757 0.35530362 0.35752118 0.35824761 0.36290187 0.36217657
#  0.36495313 0.36772823 0.36897704 0.3709054 ]
# day  17  have output =  0.37313828
# -----------------
# day  18  have input =  [0.35530362 0.35752118 0.35824761 0.36290187 0.36217657 0.36495313
#  0.36772823 0.36897704 0.3709054  0.37313828]
# day  18  have output =  0.37543285
# -----------------
# day  19  have input =  [0.35752118 0.35824761 0.36290187 0.36217657 0.36495313 0.36772823
#  0.36897704 0.3709054  0.37313828 0.37543285]
# day  19  have output =  0.37660256
# -----------------
# day  20  have input =  [0.35824761 0.36290187 0.36217657 0.36495313 0.36772823 0.36897704
#  0.3709054  0.37313828 0.37543285 0.37660256]
# day  20  have output =  0.37969068
# -----------------
# day  21  have input =  [0.36290187 0.36217657 0.36495313 0.36772823 0.36897704 0.3709054
#  0.37313828 0.37543285 0.37660256 0.37969068]
# day  21  have output =  0.38154405
# -----------------
# day  22  have input =  [0.36217657 0.36495313 0.36772823 0.36897704 0.3709054  0.37313828
#  0.37543285 0.37660256 0.37969068 0.38154405]
# day  22  have output =  0.38351634
# -----------------
# day  23  have input =  [0.36495313 0.36772823 0.36897704 0.3709054  0.37313828 0.37543285
#  0.37660256 0.37969068 0.38154405 0.38351634]
# day  23  have output =  0.38592774
# -----------------
# day  24  have input =  [0.36772823 0.36897704 0.3709054  0.37313828 0.37543285 0.37660256
#  0.37969068 0.38154405 0.38351634 0.38592774]
# day  24  have output =  0.38825485
# -----------------
# day  25  have input =  [0.36897704 0.3709054  0.37313828 0.37543285 0.37660256 0.37969068
#  0.38154405 0.38351634 0.38592774 0.38825485]
# day  25  have output =  0.39038375
# -----------------
# day  26  have input =  [0.3709054  0.37313828 0.37543285 0.37660256 0.37969068 0.38154405
#  0.38351634 0.38592774 0.38825485 0.39038375]
# day  26  have output =  0.39268637
# -----------------
# day  27  have input =  [0.37313828 0.37543285 0.37660256 0.37969068 0.38154405 0.38351634
#  0.38592774 0.38825485 0.39038375 0.39268637]
# day  27  have output =  0.39531615
# -----------------
# day  28  have input =  [0.37543285 0.37660256 0.37969068 0.38154405 0.38351634 0.38592774
#  0.38825485 0.39038375 0.39268637 0.39531615]
# day  28  have output =  0.39739758
# -----------------
# day  29  have input =  [0.37660256 0.37969068 0.38154405 0.38351634 0.38592774 0.38825485
#  0.39038375 0.39268637 0.39531615 0.39739758]
# day  29  have output =  0.3998958
# -----------------
# day  30  have input =  [0.37969068 0.38154405 0.38351634 0.38592774 0.38825485 0.39038375
#  0.39268637 0.39531615 0.39739758 0.39989579]
# day  30  have output =  0.40239915

# %%
#in ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.3415301, 0.34690478, 0.34141868, 0.34922677, 0.34943002, 0.34849244, 0.35354757, 0.35530362, 0.35752118, 0.3582476, 0.36290187, 0.36217657, 0.36495313, 0.36772823, 0.36897704, 0.3709054, 0.37313828, 0.37543285, 0.37660256, 0.37969068, 0.38154405, 0.38351634, 0.38592774, 0.38825485, 0.39038375, 0.39268637, 0.39531615, 0.39739758, 0.3998958, 0.40239915]

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[134.85]
#  [135.98]
#  [137.28]
#  [136.09]
#  [133.98]]
# [[3926.77]
#  [3434.57]
#  [3499.  ]
#  [3424.93]
#  [3208.86]]
# [[1834.08]
#  [1775.12]
#  [1804.58]
#  [1806.23]
#  [1859.84]]
# [[1713.0662]
#  [1738.328 ]
#  [1712.5425]
#  [1749.2417]
#  [1750.197 ]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Close time'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
